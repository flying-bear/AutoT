# %% [markdown]
# ## UDPipe
#
# [Инструмент](http://ufal.mff.cuni.cz/udpipe), реализующий пайплайн морфологического и синтаксического анализа, работает с разметкой Universal Dependencies.
# Есть модели, обученные на корпусах с UD (в том числе для русского).
#
# Возьмем (почти) случайную статью из Википедии и распарсим её.

# %%
wiki_text = """
Мальтийский язык (собств. наименование — malti) — язык мальтийцев, официальный язык Республики Мальта (наряду с английским), один из официальных языков Европейского союза.
Относится к семитской семье афразийской (семито-хамитской) макросемьи языков. Язык близок к арабскому, особенно к его магрибскому диалекту, однако в настоящее время считается отдельным языком со своими синтаксическими, фонетическими и лексическими особенностями.

Лингвогеография
Число говорящих — 372 тыс. чел.

Статус мальтийского языка определяется в статье 5 главы I конституции Мальты:

Национальным языком Мальты является мальтийский.
Мальтийский и английский языки, а также и другой язык, который может быть утверждён Парламентом (по закону, одобренному не менее, чем 2/3 всех членов Палаты представителей), должны быть официальными языками Мальты, и Администрация может использовать во всех своих официальных целях любой из этих языков, при условии, что любое лицо вправе обратиться к Администрации на любом из официальных языков и ответ Администрации данному лицу должен быть дан на том же языке.
Языком судопроизводства должен быть мальтийский, при условии, что парламент может издать постановление об использовании английского языка в случаях, и на условиях, определяемых в данном постановлении.
Палата представителей может, регулируя свои собственные процессуальные нормы, определить язык или языки, которые должны использоваться в работе парламента и в протоколировании.
Большинство населения Мальты двуязычно. Мальтийский язык используется в повседневном общении, в парламенте, в церкви, в СМИ, в Интернете. В разговоре мальтийский часто смешивается с английским.

На мальтийский как на официальный язык ЕС должны переводиться все официальные документы ЕС. В Интернете существует мальтийская версия портала Европейского союза.

На мальтийском языке также говорят в Австралии, в среде выходцев из Мальты и их потомков. У них сложился свой диалект — Maltraljan (Maltese Australian).

История
Во время финикийской, позже карфагенской колонизации (800 до н. э. — 218 до н. э.) население мальтийских островов говорило на одном из финикийских (пунических) языков. На финикийском наречии продолжали говорить также в период римского (с 218 до н. э.), а после разделения империи на Западную и Восточную — «восточно-римского» (византийского) владычества (в 395—870 н. э.).

В 870 году острова были завоёваны арабами. Арабский язык распространился и среди коренного населения, в частности, благодаря своему родству с финикийским. При этом разговорная речь арабов и, соответственно, местного населения отличалась от классического письменного арабского. В этот период можно говорить о существовании двух диалектов: классический арабский письменный язык и сицилийско-арабский народно-разговорный язык, центром распространения которого стал Сицилийский эмират. После вторжения норманнов сицилийско-арабский язык был постепенно вытеснен с Сицилии, однако он сохранился на небольшом периферийном острове Мальта (хотя и испытал на себе сильное романское влияние). Именно от него и происходит нынешний мальтийский язык.

Новый этап начался с норманнским завоеванием Мальты в 1090 году и присоединением её к Сицилии. Язык администрации относился к романским, и в это время произошёл новый языковой семито-романский контакт. Полной романизации населения, как и в римскую эпоху, не произошло, так как арабы продолжительное время оставались на островах и оказывали значительное культурное и языковое влияние, однако уже тогда в язык попали первые романские заимствования. Арабы покинули Мальту через 100—150 лет, и вследствие этого произошло размежевание мальтийского и арабского.

Мальта была связана с Сицилией на протяжении 440 лет, переходила вместе с ней от одной феодальной юрисдикции к другой, и в течение этого времени количество романских заимствований увеличивалось. К XV веку относится первый известный литературный текст на мальтийском языке — поэма «Il Cantilena».

Наиболее сильное романское воздействие язык получил во время правления на Мальте рыцарского ордена Святого Иоанна — с 1530 по 1798 гг. В это время письменными языками были латынь и итальянский (сицилийский и классический), однако известны отдельные попытки писать и на мальтийском, например поэма Бонамико (Bonamico), 1672. Первая опубликованная книга на мальтийском языке — катехизис Виццино (Wizzino), датируется 1752 годом.

В 1800 году Мальта была присоединена к Великобритании. Несмотря на это, в течение XIX века английский язык не занимал той важной позиции на Мальте, которую занимает сегодня, официальным письменным языком оставался итальянский, разговорным — мальтийский.

Говоря об истории мальтийского языка, следует отметить деятельность Микиля Антона Вассалли (Mikiel Anton Vassalli, 1764—1829). Он составил словарь мальтийского языка и описание мальтийской грамматики, перевёл на мальтийский часть Нового Завета.

В 1921 году Мальте было предоставлено самоуправление, по конституции официальными языками стали итальянский и английский. В 1936 году мальтийский получил статус официального языка, взамен итальянского. Мальтийский и английский остались государственными языками и после провозглашения независимости Мальты в 1964 году.

1 мая 2004 года, в связи со вступлением Мальты в ЕС, мальтийский язык стал официальным языком ЕС.

Письменность
Мальтийский — единственный из семитских языков с письменностью на основе латинского алфавита.
В алфавит иногда включают букву c (сортируется после ċ), однако эта буква встречается только в заимствованных словах, в основном итальянского и английского происхождения, напр. camping — «кэмпинг» (с другой стороны, во многих словах c заменяется на k, напр. kompjuter — «компьютер», от англ. computer).

Лингвистическая характеристика
Просодия
Ударение в мальтийском, как правило, падает на предпоследний слог, если иной слог не является долгим.

Морфология
Грамматика мальтийского языка семитского типа, с романским влиянием. Прилагательные следуют за существительными, отсутствует наречие как самостоятельная форма, порядок слов достаточно гибок. Имеется определённый артикль. Как в арабском и иврите, артикль ставится и перед существительными, и перед прилагательными, напр. L-Art l-Imqaddsa — «Святая земля» (дословный перевод — «Земля Святая»; ср. также араб. الأرض المقدسة‎, ʾAl-ʾArḍ ʾal-Muqaddasa с тем же значением). Однако это правило относится только к семитским словам и не действует при употреблении существительных и прилагательных романского происхождения.

Существительные изменяются по числам. У существительных романского происхождения множественное число образуется добавлением -i или -jiet: lingwa («язык», ср. итал. lingua) — lingwi; arti («искусство», ср. итал. arte) — artijiet. С существительными семитского происхождения всё гораздо сложнее. Такие существительные делятся на правильные и неправильные. У правильных существительных множественное число образуется добавлением -iet / -jiet (соответствует -at в арабском и -ot в иврите) или -in (соответствует -im в иврите). У неправильных же существительных множественное число образуется изменением гласных внутри: ktieb («книга») — kotba, raġel («человек») — irġiel. Такая система очень развита в арабском и встречается в иврите.

Кроме множественного числа в мальтийском языке также имеется двойственное. Оно образуется с помощью суффикса -ejn или -ajn и употребляется при указании двух или парных предметов, напр. jum («день») — jumejn («два дня»), id («рука») — idejn («обе руки»).

В глаголах можно выделить семитский корень, состоящий из трёх согласных. Глагол спрягается добавлением к этому корню внутренних гласных, а также суффиксов и приставок. Пример: ktb — корень, означающий «писать», ktibna — «мы написали» (ср. араб. katabna, иврит. katavnu с теми же значениями). Существуют два времени: настоящее и прошедшее (перфект). Для выражения будущего используются формы настоящего времени с добавлением частиц или вспомогательных глаголов.

Особенностью мальтийской глагольной системы является то, что к романским по происхождению глаголам добавляются арабские суффиксы и приставки, напр. iddeċidejna — «мы решили», где (i)ddeċieda — глагол (ср. итал. decidere), -ejna — арабский элемент, образующий форму 1-го лица множественного числа прошедшего времени. В литературном арабском и иврите такое происходит крайне редко, однако подобные формы встречаются в некоторых арабских диалектах.

Лексика
Наряду с исконным слоем семитской лексики большую роль играют романские (в основном сицилийско-итальянские, реже тосканско-итальянские) заимствования.

В базовой лексике преобладают слова арабского происхождения, а для обозначения новых идей и предметов, в качестве терминов, относящихся к государственной деятельности, юриспруденции, образованию, искусству, литературе широко используются итальянизмы. Такие слова, как raġel («человек»), mara («женщина»), tifel («ребёнок»), dar («дом»), xemx («солнце»), sajf («лето») по происхождению арабские, а skola («школа»), gvern («правительство»), repubblika («республика»), re («король»), natura («природа»), pulizija («полиция»), ċentru («центр»), teatru («театр»), differenza («разница») — романские.

Итальянские по происхождению слова обычно отражают сицилийское произношение, в то время как литературный итальянский язык происходит из тосканского диалекта. Так, конечному -o в тосканском диалекте итальянского соответствует -u в мальтийском языке, как и в сицилийском диалекте, например, teatru, а не teatro. Также тосканскому -e соответствует -i, напр. arti — «искусство», fidi — «вера», lokali — «местный житель» (ср. литературные итальянские arte, fede, locale). Как и в некоторых романских языках, звук «ш» передается буквой x, в отличие от итальянского, где для этой цели используется диграф sc: ambaxxata — «посольство» (ср. итал. ambasciata), xena — «сцена» (ср. итал. scena).

Обычным делом в современном мальтийском языке является заимствование слов из английского, например, strajk — «забастовка» (от англ. strike), televixin — «телевидение» (от англ. television), tim — «команда» (от англ. team). Некоторые слова сохраняют английское написание, например, union — «союз», «объединение», leave — «отпуск», bonus — «премия»."""

# %%
with open('wiki_text.txt', 'w', encoding='utf-8') as f:
    f.write(wiki_text)

# %% [markdown]
# **Стандартный запуск UDPipe** — последовательное применение анализаторов (токенизация, морфология, синтаксис).
# Что тут можно менять:
# * формат входа
# * формат вывода
# * настройки анализаторов

# %%
# !C:/Users/Lenovo/V/studies/HSE/prog/AutoT/sem/1/udpipe-1.2.0-bin/bin-win64/udpipe --input horizontal --output conllu \
--tokenize --tag --parse \
C:\Users\Lenovo\V\studies\HSE\prog\AutoT\sem\1\russian-syntagrus-ud-2.4-190531.udpipe \
< wiki_text.txt > wiki_text.conllu
# Out:
# Loading UDPipe model: done.

# %% [markdown]
# На самом деле, у UDPipe есть обертка для питона, но она не очень удобная, поэтому сначала записываем в файл, а потом распарсим в питонячьи структуры.

# %%
from nltk.parse import DependencyGraph

# %%
trees = []

with open('wiki_text.conllu', 'r', encoding='utf-8') as f:
    parsed_sents = f.read().split('\n\n')

    for sent in parsed_sents:
        tree = [line for line in sent.split('\n') if line and line[0] != '#']
        trees.append('\n'.join(tree))

# %%
print(trees[0])
# Out:
# 1	Мальтийский	Мальтийский	ADJ	_	Case=Nom|Degree=Pos|Gender=Masc|Number=Sing	2	amod	_	SpacesBefore=\r\n
# 2	язык	язык	NOUN	_	Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing	0	root	_	_
# 3	(	(	PUNCT	_	_	4	punct	_	SpaceAfter=No
# 4	собств	собство	NOUN	_	Animacy=Inan|Case=Gen|Gender=Neut|Number=Plur	2	parataxis	_	SpaceAfter=No
# 5	.	.	PUNCT	_	_	4	punct	_	_
# 6	наименование	наименование	NOUN	_	Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing	4	parataxis	_	_
# 7	—	—	PUNCT	_	_	6	punct	_	_
# 8	malti	malti	X	_	Foreign=Yes	6	flat:foreign	_	SpaceAfter=No
# 9	)	)	PUNCT	_	_	8	punct	_	_
# 10	—	—	PUNCT	_	_	11	punct	_	_
# 11	язык	язык	NOUN	_	Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing	6	conj	_	_
# 12	мальтийцев	мальтиец	NOUN	_	Animacy=Anim|Case=Gen|Gender=Masc|Number=Plur	11	nmod	_	SpaceAfter=No
# 13	,	,	PUNCT	_	_	15	punct	_	_
# 14	официальный	официальный	ADJ	_	Case=Nom|Degree=Pos|Gender=Masc|Number=Sing	15	amod	_	_
# 15	язык	язык	NOUN	_	Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing	6	conj	_	_
# 16	Республики	Республика	PROPN	_	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	15	nmod	_	_
# 17	Мальта	Мальта	PROPN	_	Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing	16	appos	_	_
# 18	(	(	PUNCT	_	_	19	punct	_	SpaceAfter=No
# 19	наряду	наряду	ADV	_	Degree=Pos	15	parataxis	_	_
# 20	с	с	ADP	_	_	21	case	_	_
# 21	английским	английский	ADJ	_	Case=Ins|Degree=Pos|Gender=Masc|Number=Sing	19	obl	_	SpaceAfter=No
# 22	)	)	PUNCT	_	_	19	punct	_	SpaceAfter=No
# 23	,	,	PUNCT	_	_	24	punct	_	_
# 24	один	один	NUM	_	Case=Nom|Gender=Masc	6	conj	_	_
# 25	из	из	ADP	_	_	27	case	_	_
# 26	официальных	официальный	ADJ	_	Case=Gen|Degree=Pos|Number=Plur	27	amod	_	_
# 27	языков	язык	NOUN	_	Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur	24	nmod	_	_
# 28	Европейского	Европейский	PROPN	_	_	29	amod	_	_
# 29	союза	союз	NOUN	_	Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing	27	nmod	_	SpaceAfter=No
# 30	.	.	PUNCT	_	_	4	punct	_	SpacesAfter=\r\n

# %%
g = DependencyGraph(trees[0], top_relation_label='root')

# %%
help(g)
# Out:
# Help on DependencyGraph in module nltk.parse.dependencygraph object:
#
# class DependencyGraph(builtins.object)
#  |  A container for the nodes and labelled edges of a dependency structure.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, tree_str=None, cell_extractor=None, zero_based=False, cell_separator=None, top_relation_label='ROOT')
#  |      Dependency graph.
#  |
#  |      We place a dummy `TOP` node with the index 0, since the root node is
#  |      often assigned 0 as its head. This also means that the indexing of the
#  |      nodes corresponds directly to the Malt-TAB format, which starts at 1.
#  |
#  |      If zero-based is True, then Malt-TAB-like input with node numbers
#  |      starting at 0 and the root node assigned -1 (as produced by, e.g.,
#  |      zpar).
#  |
#  |      :param str cell_separator: the cell separator. If not provided, cells
#  |      are split by whitespace.
#  |
#  |      :param str top_relation_label: the label by which the top relation is
#  |      identified, for examlple, `ROOT`, `null` or `TOP`.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  __str__(self)
#  |      Return str(self).
#  |
#  |  __unicode__ = __str__(self)
#  |
#  |  add_arc(self, head_address, mod_address)
#  |      Adds an arc from the node specified by head_address to the
#  |      node specified by the mod address.
#  |
#  |  add_node(self, node)
#  |
#  |  connect_graph(self)
#  |      Fully connects all non-root nodes.  All nodes are set to be dependents
#  |      of the root node.
#  |
#  |  contains_address(self, node_address)
#  |      Returns true if the graph contains a node with the given node
#  |      address, false otherwise.
#  |
#  |  contains_cycle(self)
#  |      Check whether there are cycles.
#  |
#  |      >>> dg = DependencyGraph(treebank_data)
#  |      >>> dg.contains_cycle()
#  |      False
#  |
#  |      >>> cyclic_dg = DependencyGraph()
#  |      >>> top = {'word': None, 'deps': [1], 'rel': 'TOP', 'address': 0}
#  |      >>> child1 = {'word': None, 'deps': [2], 'rel': 'NTOP', 'address': 1}
#  |      >>> child2 = {'word': None, 'deps': [4], 'rel': 'NTOP', 'address': 2}
#  |      >>> child3 = {'word': None, 'deps': [1], 'rel': 'NTOP', 'address': 3}
#  |      >>> child4 = {'word': None, 'deps': [3], 'rel': 'NTOP', 'address': 4}
#  |      >>> cyclic_dg.nodes = {
#  |      ...     0: top,
#  |      ...     1: child1,
#  |      ...     2: child2,
#  |      ...     3: child3,
#  |      ...     4: child4,
#  |      ... }
#  |      >>> cyclic_dg.root = top
#  |
#  |      >>> cyclic_dg.contains_cycle()
#  |      [3, 1, 2, 4]
#  |
#  |  get_by_address(self, node_address)
#  |      Return the node with the given address.
#  |
#  |  get_cycle_path(self, curr_node, goal_node_index)
#  |
#  |  left_children(self, node_index)
#  |      Returns the number of left children under the node specified
#  |      by the given address.
#  |
#  |  nx_graph(self)
#  |      Convert the data in a ``nodelist`` into a networkx labeled directed graph.
#  |
#  |  redirect_arcs(self, originals, redirect)
#  |      Redirects arcs to any of the nodes in the originals list
#  |      to the redirect node address.
#  |
#  |  remove_by_address(self, address)
#  |      Removes the node with the given address.  References
#  |      to this node in others will still exist.
#  |
#  |  right_children(self, node_index)
#  |      Returns the number of right children under the node specified
#  |      by the given address.
#  |
#  |  to_conll(self, style)
#  |      The dependency graph in CoNLL format.
#  |
#  |      :param style: the style to use for the format (3, 4, 10 columns)
#  |      :type style: int
#  |      :rtype: str
#  |
#  |  to_dot(self)
#  |      Return a dot representation suitable for using with Graphviz.
#  |
#  |      >>> dg = DependencyGraph(
#  |      ...     'John N 2\n'
#  |      ...     'loves V 0\n'
#  |      ...     'Mary N 2'
#  |      ... )
#  |      >>> print(dg.to_dot())
#  |      digraph G{
#  |      edge [dir=forward]
#  |      node [shape=plaintext]
#  |      <BLANKLINE>
#  |      0 [label="0 (None)"]
#  |      0 -> 2 [label="ROOT"]
#  |      1 [label="1 (John)"]
#  |      2 [label="2 (loves)"]
#  |      2 -> 1 [label=""]
#  |      2 -> 3 [label=""]
#  |      3 [label="3 (Mary)"]
#  |      }
#  |
#  |  tree(self)
#  |      Starting with the ``root`` node, build a dependency tree using the NLTK
#  |      ``Tree`` constructor. Dependency labels are omitted.
#  |
#  |  triples(self, node=None)
#  |      Extract dependency triples of the form:
#  |      ((head word, head tag), rel, (dep word, dep tag))
#  |
#  |  unicode_repr = __repr__(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  load(filename, zero_based=False, cell_separator=None, top_relation_label='ROOT')
#  |      :param filename: a name of a file in Malt-TAB format
#  |      :param zero_based: nodes in the input file are numbered starting from 0
#  |      rather than 1 (as produced by, e.g., zpar)
#  |      :param str cell_separator: the cell separator. If not provided, cells
#  |      are split by whitespace.
#  |      :param str top_relation_label: the label by which the top relation is
#  |      identified, for examlple, `ROOT`, `null` or `TOP`.
#  |
#  |      :return: a list of DependencyGraphs
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
print(g.root)
# Out:
# {'address': 2, 'word': 'язык', 'lemma': 'язык', 'ctag': 'NOUN', 'tag': '_', 'feats': 'Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing', 'head': 0, 'deps': defaultdict(<class 'list'>, {'amod': [1], 'parataxis': [4]}), 'rel': 'root'}

# %%
for t in g.triples():
    print(t)
# Out:
# (('язык', 'NOUN'), 'amod', ('Мальтийский', 'ADJ'))
# (('язык', 'NOUN'), 'parataxis', ('собств', 'NOUN'))
# (('собств', 'NOUN'), 'punct', ('(', 'PUNCT'))
# (('собств', 'NOUN'), 'punct', ('.', 'PUNCT'))
# (('собств', 'NOUN'), 'parataxis', ('наименование', 'NOUN'))
# (('наименование', 'NOUN'), 'punct', ('—', 'PUNCT'))
# (('наименование', 'NOUN'), 'flat:foreign', ('malti', 'X'))
# (('malti', 'X'), 'punct', (')', 'PUNCT'))
# (('наименование', 'NOUN'), 'conj', ('язык', 'NOUN'))
# (('язык', 'NOUN'), 'punct', ('—', 'PUNCT'))
# (('язык', 'NOUN'), 'nmod', ('мальтийцев', 'NOUN'))
# (('наименование', 'NOUN'), 'conj', ('язык', 'NOUN'))
# (('язык', 'NOUN'), 'punct', (',', 'PUNCT'))
# (('язык', 'NOUN'), 'amod', ('официальный', 'ADJ'))
# (('язык', 'NOUN'), 'nmod', ('Республики', 'PROPN'))
# (('Республики', 'PROPN'), 'appos', ('Мальта', 'PROPN'))
# (('язык', 'NOUN'), 'parataxis', ('наряду', 'ADV'))
# (('наряду', 'ADV'), 'punct', ('(', 'PUNCT'))
# (('наряду', 'ADV'), 'obl', ('английским', 'ADJ'))
# (('английским', 'ADJ'), 'case', ('с', 'ADP'))
# (('наряду', 'ADV'), 'punct', (')', 'PUNCT'))
# (('наименование', 'NOUN'), 'conj', ('один', 'NUM'))
# (('один', 'NUM'), 'punct', (',', 'PUNCT'))
# (('один', 'NUM'), 'nmod', ('языков', 'NOUN'))
# (('языков', 'NOUN'), 'case', ('из', 'ADP'))
# (('языков', 'NOUN'), 'amod', ('официальных', 'ADJ'))
# (('языков', 'NOUN'), 'nmod', ('союза', 'NOUN'))
# (('союза', 'NOUN'), 'amod', ('Европейского', 'PROPN'))
# (('собств', 'NOUN'), 'punct', ('.', 'PUNCT'))

# %%
for n in g.nodes:
    if g.nodes[n]['ctag'] == 'NOUN':
        print(n, g.nodes[n])
# Out:
# 2 {'address': 2, 'word': 'язык', 'lemma': 'язык', 'ctag': 'NOUN', 'tag': '_', 'feats': 'Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing', 'head': 0, 'deps': defaultdict(<class 'list'>, {'amod': [1], 'parataxis': [4]}), 'rel': 'root'}
# 4 {'address': 4, 'word': 'собств', 'lemma': 'собство', 'ctag': 'NOUN', 'tag': '_', 'feats': 'Animacy=Inan|Case=Gen|Gender=Neut|Number=Plur', 'head': 2, 'deps': defaultdict(<class 'list'>, {'punct': [3, 5, 30], 'parataxis': [6]}), 'rel': 'parataxis'}
# 6 {'address': 6, 'word': 'наименование', 'lemma': 'наименование', 'ctag': 'NOUN', 'tag': '_', 'feats': 'Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing', 'head': 4, 'deps': defaultdict(<class 'list'>, {'punct': [7], 'flat:foreign': [8], 'conj': [11, 15, 24]}), 'rel': 'parataxis'}
# 11 {'address': 11, 'word': 'язык', 'lemma': 'язык', 'ctag': 'NOUN', 'tag': '_', 'feats': 'Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing', 'head': 6, 'deps': defaultdict(<class 'list'>, {'punct': [10], 'nmod': [12]}), 'rel': 'conj'}
# 12 {'address': 12, 'word': 'мальтийцев', 'lemma': 'мальтиец', 'ctag': 'NOUN', 'tag': '_', 'feats': 'Animacy=Anim|Case=Gen|Gender=Masc|Number=Plur', 'head': 11, 'deps': defaultdict(<class 'list'>, {}), 'rel': 'nmod'}
# 15 {'address': 15, 'word': 'язык', 'lemma': 'язык', 'ctag': 'NOUN', 'tag': '_', 'feats': 'Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing', 'head': 6, 'deps': defaultdict(<class 'list'>, {'punct': [13], 'amod': [14], 'nmod': [16], 'parataxis': [19]}), 'rel': 'conj'}
# 27 {'address': 27, 'word': 'языков', 'lemma': 'язык', 'ctag': 'NOUN', 'tag': '_', 'feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur', 'head': 24, 'deps': defaultdict(<class 'list'>, {'case': [25], 'amod': [26], 'nmod': [29]}), 'rel': 'nmod'}
# 29 {'address': 29, 'word': 'союза', 'lemma': 'союз', 'ctag': 'NOUN', 'tag': '_', 'feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 'head': 27, 'deps': defaultdict(<class 'list'>, {'amod': [28]}), 'rel': 'nmod'}

# %% [markdown]
# Давайте заведем функцию, которая будет собирать (максимальное) поддерево, корнем которого является заданная вершина.

# %%
_FILTER_RELS = ['punct', 'conj', 'parataxis']
def get_subtree(nodes, node):
    if not nodes[node]['deps']:
        return [node]
    else:
        return [node] + [get_subtree(nodes, dep) for rel in nodes[node]['deps'] 
                         if rel not in _FILTER_RELS
                         for dep in nodes[node]['deps'][rel]]

# %% [markdown]
# Чтобы потом получить просто индексы для выделения групп, нужно разобраться со вложенностью.

# %%
def flatten(l):
    flat = []
    for el in l:
        if not isinstance(el, list):
            flat.append(el)
        else:
            flat += flatten(el)
    return flat

# %% [markdown]
# Всё готово, чтобы попробовать достать именные группы.

# %%
np_list = []
for n in g.nodes:
    if g.nodes[n]['ctag'] == 'NOUN':
        np = list(sorted(flatten(get_subtree(g.nodes, n))))
        np_list.append(
            ' '.join([g.nodes[i]['word'] for i in np])
        )

# %%
np_list
# Out:
# ['Мальтийский язык',
#  'собств',
#  'наименование malti',
#  'язык мальтийцев',
#  'мальтийцев',
#  'официальный язык Республики Мальта',
#  'из официальных языков Европейского союза',
#  'Европейского союза']

# %% [markdown]
# А теперь всё то же самое для всего текста.

# %%
result = []
for t in trees:
    g = DependencyGraph(t, top_relation_label='root')
    np_list = []
    for n in g.nodes:
        if g.nodes[n]['ctag'] == 'NOUN':
            np = list(sorted(flatten(get_subtree(g.nodes, n))))
            np_list.append(' '.join([g.nodes[i]['word'] for i in np]))
    result.append(np_list)

# %%
result
# Out:
# [['Мальтийский язык',
#   'собств',
#   'наименование malti',
#   'язык мальтийцев',
#   'мальтийцев',
#   'официальный язык Республики Мальта',
#   'из официальных языков Европейского союза',
#   'Европейского союза'],
#  ['к семитской семье афразийской семито-хамитской макросемьи языков',
#   'афразийской семито-хамитской макросемьи языков',
#   'языков'],
#  ['Язык',
#   'особенно к его магрибскому диалекту',
#   'время',
#   'отдельным языком',
#   'со своими синтаксическими особенностями'],
#  ['Лингвогеография',
#   'Лингвогеография Число говорящих 372 тыс. чел',
#   '372 тыс. чел',
#   'чел'],
#  ['Статус мальтийского языка',
#   'мальтийского языка',
#   'в статье 5 главы I конституции Мальты',
#   '5 главы I конституции Мальты',
#   'I конституции Мальты'],
#  ['Национальным языком Мальты'],
#  ['Мальтийский языки',
#   'а также и другой язык который может быть утверждён Парламентом',
#   'по закону',
#   'не менее чем 2 3 всех членов Палаты представителей',
#   'представителей',
#   'быть официальными языками Мальты',
#   'во всех своих официальных целях',
#   'из этих языков',
#   'при условии что любое лицо вправе обратиться к Администрации на любом из официальных языков и ответ Администрации данному лицу должен быть дан на том же языке',
#   'любое лицо',
#   'из официальных языков',
#   'и ответ Администрации данному лицу',
#   'данному лицу',
#   'на том же языке'],
#  ['Языком судопроизводства быть',
#   'судопроизводства',
#   'при условии что парламент может издать постановление об использовании английского языка в случаях',
#   'парламент',
#   'постановление об использовании английского языка в случаях',
#   'об использовании английского языка в случаях',
#   'английского языка',
#   'в случаях',
#   'и на условиях определяемых в данном постановлении',
#   'в данном постановлении'],
#  ['Палата представителей',
#   'представителей',
#   'свои собственные процессуальные нормы',
#   'язык которые должны использоваться в работе парламента',
#   'или языки',
#   'в работе парламента',
#   'парламента',
#   'и в протоколировании'],
#  ['Большинство населения Мальты', 'населения Мальты'],
#  ['Мальтийский язык',
#   'в повседневном общении',
#   'в парламенте',
#   'в церкви',
#   'в СМИ'],
#  ['В разговоре'],
#  ['как на официальный язык', 'все официальные документы ЕС'],
#  ['мальтийская версия портала Европейского союза',
#   'портала Европейского союза',
#   'Европейского союза'],
#  ['На мальтийском языке',
#   'в среде выходцев из Мальты',
#   'выходцев из Мальты',
#   'и их потомков'],
#  ['свой диалект Maltraljan Maltese Australian'],
#  ['История',
#   'Во время финикийской позже карфагенской колонизации',
#   'время',
#   'до н. э. 218 до н. э.',
#   'до н. э.',
#   'население мальтийских островов',
#   'мальтийских островов',
#   'из финикийских пунических языков'],
#  ['На финикийском наречии',
#   'в период римского с 218 до н. э.',
#   'до н. э.',
#   'а после разделения империи на Западную',
#   'империи',
#   '«восточно римского» владычества',
#   'владычества',
#   'в 395 870 н. э.'],
#  ['В 870 году', 'острова', 'арабами'],
#  ['Арабский язык',
#   'и среди коренного населения',
#   'в частности благодаря своему родству с финикийским',
#   'частности'],
#  ['При этом разговорная речь арабов', 'арабов', 'местного населения'],
#  ['В этот период',
#   'о существовании двух диалектов',
#   'двух диалектов',
#   'классический арабский письменный язык центром распространения которого стал Сицилийский эмират',
#   'и сицилийско арабский народно разговорный язык',
#   'центром распространения которого',
#   'распространения которого',
#   'Сицилийский эмират'],
#  ['После вторжения норманнов',
#   'норманнов',
#   'сицилийско арабский язык',
#   'на небольшом периферийном острове Мальта',
#   'сильное романское влияние'],
#  ['нынешний мальтийский язык'],
#  ['Новый этап',
#   'с норманнским завоеванием Мальты',
#   'в 1090 году',
#   'и присоединением её к Сицилии',
#   'к Сицилии'],
#  ['Язык администрации',
#   'администрации',
#   'в это время',
#   'новый языковой семито-романский контакт'],
#  ['Полной романизации населения как и в римскую эпоху',
#   'населения',
#   'как и в римскую эпоху',
#   'продолжительное время',
#   'на островах',
#   'значительное культурное влияние',
#   'в язык',
#   'первые романские заимствования'],
#  ['через 100 150 лет', 'размежевание мальтийского'],
#  ['Мальта',
#   'на протяжении 440 лет',
#   '440 лет',
#   'от одной феодальной юрисдикции к другой',
#   'в течение этого времени',
#   'течение',
#   'количество романских заимствований',
#   'романских заимствований'],
#  ['К XV веку',
#   'первый известный литературный текст на мальтийском языке поэма «Il Cantilena»',
#   'на мальтийском языке',
#   'поэма «Il Cantilena»',
#   'Cantilena»'],
#  ['Наиболее сильное романское воздействие язык',
#   'язык',
#   'во время правления на Мальте рыцарского ордена Святого Иоанна',
#   'время',
#   'рыцарского ордена Святого Иоанна',
#   'по 1798 гг'],
#  ['В это время',
#   'В это время письменными языками были латынь',
#   'латынь',
#   'отдельные попытки писать'],
#  ['Первая опубликованная книга на мальтийском языке катехизис Виццино Wizzino',
#   'на мальтийском языке',
#   'катехизис Виццино Wizzino',
#   '1752 годом'],
#  ['В 1800 году'],
#  ['в течение XIX века',
#   'течение',
#   'английский язык',
#   'той важной позиции на Мальте которую занимает сегодня',
#   'официальным письменным языком'],
#  ['об истории мальтийского языка',
#   'мальтийского языка',
#   'деятельность Микиля Антона Вассалли Mikiel Anton Vassalli 1764 1829'],
#  ['словарь мальтийского языка',
#   'мальтийского языка',
#   'и описание мальтийской грамматики',
#   'мальтийской грамматики',
#   'на мальтийский часть Нового Завета'],
#  ['В 1921 году',
#   'самоуправление',
#   'по конституции официальными языками',
#   'официальными языками'],
#  ['В 1936 году', 'статус официального языка', 'официального языка'],
#  ['государственными языками',
#   'и после провозглашения независимости Мальты в 1964 году',
#   'независимости Мальты',
#   'в 1964 году'],
#  ['мая',
#   '2004 года',
#   'в связи со вступлением Мальты в ЕС',
#   'связи',
#   'мальтийский язык',
#   'официальным языком ЕС'],
#  ['Письменность Мальтийский единственный из семитских языков с письменностью на основе латинского алфавита',
#   'из семитских языков',
#   'с письменностью на основе латинского алфавита',
#   'на основе латинского алфавита',
#   'латинского алфавита'],
#  ['В алфавит',
#   'букву c',
#   'после ċ',
#   'эта буква',
#   'только в заимствованных словах',
#   'в основном итальянского происхождения',
#   '«кэмпинг»',
#   'с другой стороны',
#   'во многих словах',
#   'напр'],
#  ['«компьютер»', 'от англ. computer'],
#  ['Лингвистическая характеристика Просодия',
#   'Лингвистическая характеристика Просодия Ударение в мальтийском',
#   'как правило',
#   'на предпоследний слог',
#   'иной слог'],
#  ['Морфология Грамматика мальтийского языка семитского типа с романским влиянием',
#   'Грамматика мальтийского языка семитского типа',
#   'семитского типа',
#   'с романским влиянием'],
#  ['наречие',
#   'как самостоятельная форма',
#   'порядок слов достаточно гибок',
#   'порядок слов',
#   'слов'],
#  ['определённый артикль'],
#  ['и иврите',
#   'артикль',
#   'напр. L-Art l-Imqaddsa «Святая земля»',
#   '«Святая земля»',
#   'дословный перевод «Земля Святая»',
#   '«Земля Святая»',
#   'Святая»',
#   'араб الأرض المقدسة\u200e ʾAl-ʾArḍ ʾal-Muqaddasa с тем же значением',
#   'الأرض المقدسة\u200e ʾAl-ʾArḍ ʾal-Muqaddasa',
#   'المقدسة\u200e ʾAl-ʾArḍ ʾal-Muqaddasa',
#   'ʾAl-ʾArḍ ʾal-Muqaddasa',
#   'с тем же значением'],
#  ['это правило',
#   'только к семитским словам',
#   'при употреблении существительных романского происхождения',
#   'существительных романского происхождения'],
#  ['по числам'],
#  ['У существительных романского происхождения',
#   'множественное число',
#   'добавлением i',
#   '«язык» ср. итал lingua lingwi',
#   '«искусство» ср. итал arte artijiet'],
#  ['С существительными семитского происхождения'],
#  [],
#  ['У правильных существительных множественное число',
#   'добавлением',
#   'в иврите',
#   'im в иврите'],
#  ['У неправильных же существительных множественное число',
#   'изменением гласных внутри',
#   'ktieb «книга» kotba raġel irġiel',
#   '«книга»',
#   '«человек»'],
#  ['Такая система', 'в иврите'],
#  ['Кроме множественного числа в мальтийском языке', 'в мальтийском языке'],
#  ['с помощью суффикса',
#   'помощью',
#   'ejn',
#   'или ajn',
#   'при указании двух предметов',
#   'двух предметов',
#   'напр'],
#  ['«день»', '«два дня»', '«рука»', 'руки»'],
#  ['В глаголах', 'семитский корень состоящий из трёх согласных'],
#  ['Глагол',
#   'добавлением',
#   'к этому корню внутренних гласных',
#   'а также суффиксов',
#   'и приставок'],
#  ['Пример',
#   'ktb',
#   'корень означающий «писать» ktibna «мы написали»',
#   '«писать» ktibna «мы написали»',
#   '«мы написали»',
#   'написали»',
#   'араб',
#   'с теми же значениями'],
#  ['два времени', 'перфект'],
#  ['Для выражения будущего',
#   'будущего',
#   'формы настоящего времени с добавлением частиц',
#   'настоящего времени',
#   'с добавлением частиц',
#   'частиц',
#   'или вспомогательных глаголов'],
#  ['Особенностью мальтийской глагольной системы',
#   'мальтийской глагольной системы',
#   'по происхождению',
#   'арабские суффиксы',
#   'и приставки',
#   '«мы решили» где i)ddeċieda',
#   'решили» где i)ddeċieda',
#   'глагол -ejna',
#   'арабский элемент образующий форму 1-го лица множественного числа прошедшего времени',
#   'форму 1-го лица множественного числа прошедшего времени',
#   '1-го лица множественного числа прошедшего времени',
#   'множественного числа прошедшего времени',
#   'прошедшего времени'],
#  ['и иврите', 'подобные формы', 'в некоторых арабских диалектах'],
#  ['Лексика',
#   'с исконным слоем семитской лексики',
#   'семитской лексики',
#   'большую роль',
#   'романские заимствования'],
#  ['В базовой лексике',
#   'слова арабского происхождения',
#   'арабского происхождения',
#   'а для обозначения новых идей',
#   'новых идей',
#   'и предметов относящихся к государственной деятельности',
#   'в качестве терминов',
#   'качестве',
#   'к государственной деятельности',
#   'юриспруденции',
#   'образованию',
#   'искусству',
#   'литературе',
#   'итальянизмы'],
#  ['Такие слова',
#   '«человек»',
#   '«женщина»',
#   '«ребёнок»',
#   '«дом»',
#   '«солнце»',
#   '«лето»',
#   'по происхождению арабские',
#   '«школа»',
#   '«правительство»',
#   '«республика»',
#   '«король»',
#   '«природа»',
#   '«полиция»',
#   '«центр»',
#   '«театр»',
#   '«разница»'],
#  ['по происхождению слова',
#   'слова',
#   'сицилийское произношение',
#   'время',
#   'литературный итальянский язык',
#   'из тосканского диалекта'],
#  ['конечному -o',
#   'в тосканском диалекте итальянского',
#   'в мальтийском языке как и в сицилийском диалекте',
#   'как и в сицилийском диалекте',
#   'а не teatro'],
#  ['напр. arti «искусство» fidi «вера» lokali «местный житель»',
#   '«искусство» fidi «вера» lokali «местный житель»',
#   '«вера» lokali «местный житель»',
#   '«местный житель»'],
#  ['Как и в некоторых романских языках',
#   'звук «ш»',
#   '«ш»',
#   'отличие',
#   'для этой цели',
#   'диграф sc',
#   '«посольство» ср.',
#   '«сцена»'],
#  ['Обычным делом в современном мальтийском языке',
#   'в современном мальтийском языке',
#   'заимствование слов из английского',
#   'слов из английского',
#   '«забастовка» televixin',
#   '«телевидение» tim',
#   '«команда»'],
#  ['Некоторые слова',
#   'английское написание',
#   '«союз»',
#   '«объединение»',
#   '«отпуск»',
#   '«премия»'],
#  []]

# %% [markdown]
# ## Выделение ключевых слов (keyword extraction)
#
# Наконец перейдем к основной теме занятия (UDPipe тоже может понадобиться).
#
# В основном алгоритмы выделения ключевых слов - "unsupervised", используют какие-то количественные данные о встречаемости слов в текстах, чтобы выделить самые значимые (звучит логично).
#
# Итак, от простого к сложному:
# * частоты слов / словосочетаний
# * ${tf} \cdot {idf}$
# * C-value
# * RAKE
# * TextRank
# * ...
#
# Какие могут быть проблемы?..

# %%
#!pip3.7 install python-rake

# %% [markdown]
# **RAKE** — это алгоритм для извлечения ключевых слов, который учитывает частоты отдельных слов и их совместную встречаемость. Сначала делим текст на слова (токены), затем по стоп-словам и маркерам границ фраз делим на фразы. Потом строим матрицу совместной встречаемости (все слова * все слова). Значимость слова оценивается, как отношение степени слова (сколько других слов встретилось с ним в фразе) к частоте слова.
#
# *Подробнее в слайдах к лекции.*

# %% [markdown]
# Итак, нам нужны стоп-слова (забудем пока о границах фраз) и токенизация -> NLTK.

# %%
import RAKE

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
stop = stopwords.words('russian')

# %%
stop
# Out:
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
#  'тоже',
#  'себе',
#  'под',
#  'будет',
#  'ж',
#  'тогда',
#  'кто',
#  'этот',
#  'того',
#  'потому',
#  'этого',
#  'какой',
#  'совсем',
#  'ним',
#  'здесь',
#  'этом',
#  'один',
#  'почти',
#  'мой',
#  'тем',
#  'чтобы',
#  'нее',
#  'сейчас',
#  'были',
#  'куда',
#  'зачем',
#  'всех',
#  'никогда',
#  'можно',
#  'при',
#  'наконец',
#  'два',
#  'об',
#  'другой',
#  'хоть',
#  'после',
#  'над',
#  'больше',
#  'тот',
#  'через',
#  'эти',
#  'нас',
#  'про',
#  'всего',
#  'них',
#  'какая',
#  'много',
#  'разве',
#  'три',
#  'эту',
#  'моя',
#  'впрочем',
#  'хорошо',
#  'свою',
#  'этой',
#  'перед',
#  'иногда',
#  'лучше',
#  'чуть',
#  'том',
#  'нельзя',
#  'такой',
#  'им',
#  'более',
#  'всегда',
#  'конечно',
#  'всю',
#  'между']

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Инициализируем анализатор списком стоп-слов
rake = RAKE.Rake(stop)

# %%
# Запускаем
wiki_kw_list = rake.run(wiki_text, maxWords=3, minFrequency=2)

# %%
rake.run('я такой дурак дурак дураком что делать я даже не знаю', maxWords=3, minFrequency=1)
# Out:
# [('дурак дурак дураком', 9.0), ('делать', 1.0), ('знаю', 1.0)]

# %%
wiki_kw_list
# Out:
# [('мальтийский', 1.5714285714285714),
#  ('например', 1.5),
#  ('романским', 1.3333333333333333),
#  ('мальтийском', 1.3333333333333333),
#  ('арабском', 1.25),
#  ('английским', 1.0),
#  ('однако', 1.0),
#  ('условии', 1.0),
#  ('н', 1.0),
#  ('э', 1.0),
#  ('сицилии', 1.0),
#  ('напр', 1.0),
#  ('англ', 1.0),
#  ('существительными', 1.0),
#  ('иврите', 1.0),
#  ('ср', 1.0),
#  ('итал', 1.0),
#  ('raġel', 1.0),
#  ('«человек»', 1.0),
#  ('teatru', 1.0)]

# %% [markdown]
# Можно вспомнить, что мы вытаскивали из этого текста именные группы. А часто именно они представляют собой ключевые фразы.

# %%
set([x[0] for x in wiki_kw_list]) & set(flatten(result))
# Out:
# {'«человек»', 'напр'}

# %% [markdown]
# Похоже, для отдельных слов можно применить лемматизацию и станет лучше.
# А ещё токенизировать красиво.

# %%
from pymorphy2 import MorphAnalyzer
from pymorphy2.tokenizers import simple_word_tokenize

# %%
morph = MorphAnalyzer()
def normalize_text(text):
    lemmas = [morph.parse(word)[0].normal_form for word in nltk.word_tokenize(text)]
    return ' '.join(lemmas)

# %%
rake.run(normalize_text(wiki_text), maxWords=3, minFrequency=2)
# Out:
# [('мальтийский язык', 3.95),
#  ('язык', 2.2),
#  ('мальта', 2.1),
#  ('арабский', 2.090909090909091),
#  ('относиться', 2.0),
#  ('романский', 2.0),
#  ('итальянский', 2.0),
#  ('мальтийский', 1.75),
#  ('существительное', 1.6),
#  ('английский', 1.5714285714285714),
#  ('время', 1.5),
#  ('финикийский', 1.3333333333333333),
#  ('например', 1.2),
#  ('однако', 1.0),
#  ('условие', 1.0),
#  ('э', 1.0),
#  ('наш', 1.0),
#  ('говорить', 1.0),
#  ('сицилия', 1.0),
#  ('англ', 1.0),
#  ('иврит', 1.0),
#  ('сравнить', 1.0),
#  ('значение', 1.0),
#  ('италый', 1.0),
#  ('неправильный', 1.0),
#  ('raġel', 1.0),
#  ('« человек »', 1.0),
#  ('приставка', 1.0),
#  ('teatru', 1.0)]

# %% [markdown]
# Выглядит симпатичнее. И словосочетания появились.
#
# *Бонус-трек для домашки*: можно оставить в тексте только именные группы и посмотреть, что получится.

# %% [markdown]
# Попробуем какой-нибудь другой жанр, например, **новости**.

# %%
bbc_text = """
Королева Британии Елизавета II приняла решение отказаться от одежды и аксессуаров из натурального меха, сообщил Букингемский дворец. Некоторые королевские наряды уже перешиты.
О том, что королева отказывается от натурального меха, написала в своей книге "Другая сторона монеты: королева, модельер и платяной шкаф" личный костюмер королевы Анджела Келли.
"Если Ее Величеству придется посещать какое-либо мероприятие в очень холодную погоду, с 2019 года, чтобы не замерзнуть, она будет надевать одежду из искусственного меха", - рассказала личный костюмер королевы Анджела Келли.
Пресс-секретарь Букингемского дворца подтвердил, что для пошива новой одежды для королевы при необходимости будет использоваться только искусственный мех.
При этом, как уточнили в Букингемском дворце, королева продолжит носить те меховые изделия, которые были приобретены или созданы для нее ранее - от шляп до церемониальных мантий.
В своей книге Анджела Келли рассказывает, что мех норки на пальто, которое было на королеве во время ее визита в Словакию в 2008 году, сейчас заменен на искусственный.
Королеву неоднократно критиковали за то, что она продолжала носить меховые изделия, когда от использования меха отказались почти все модные дома, признав использование меха для изготовления одежды и аксессуаров жестоким решением.
"""

# %%
rake.run(bbc_text, minFrequency=2, maxWords=3)
# Out:
# [('натурального меха', 4.4)]

# %%
rake.run(normalize_text(bbc_text), minFrequency=2, maxWords=3)
# Out:
# [('натуральный мех', 4.285714285714286),
#  ('искусственный мех', 3.9523809523809526),
#  ('королева', 1.8333333333333333),
#  ('который', 1.0)]

# %% [markdown]
# А стоп-слова вообще работают? Давайте добавим слово "который".

# %%
stop.append('который')

# %%
rake = RAKE.Rake(stop)
rake.run(normalize_text(bbc_text), minFrequency=2, maxWords=3)
# Out:
# [('натуральный мех', 4.285714285714286),
#  ('искусственный мех', 3.9523809523809526),
#  ('королева', 1.8333333333333333)]

# %% [markdown]
# Ну и наконец сложно формализуемый текст.

# %%
fiction_text = """
Ваши превосходительства, высокородия, благородия, граждане!
– –
Что есть Русская Империя наша?
Русская Империя наша есть географическое единство, что значит: часть известной планеты. И Русская Империя заключает: во-первых – великую, малую, белую и червонную Русь; во-вторых – грузинское, польское, казанское и астраханское царство; в-третьих, она заключает… Но – прочая, прочая, прочая.
Русская Империя наша состоит из множества городов: столичных, губернских, уездных, заштатных; и далее: – из первопрестольного града и матери градов русских.
Град первопрестольный – Москва; и мать градов русских есть Киев.
Петербург, или Санкт-Петербург, или Питер (что – то же) подлинно принадлежит Российской Империи. А Царьград, Константиноград (или, как говорят, Константинополь), принадлежит по праву наследия. И о нем распространяться не будем.
Распространимся более о Петербурге: есть – Петербург, или Санкт-Петербург, или Питер (что – то же). На основании тех же суждений Невский Проспект есть петербургский Проспект.
Невский Проспект обладает разительным свойством: он состоит из пространства для циркуляции публики; нумерованные дома ограничивают его; нумерация идет в порядке домов – и поиски нужного дома весьма облегчаются. Невский Проспект, как и всякий проспект, есть публичный проспект; то есть: проспект для циркуляции публики (не воздуха, например); образующие его боковые границы дома суть – гм… да:… для публики. Невский Проспект по вечерам освещается электричеством. Днем же Невский Проспект не требует освещения.
Невский Проспект прямолинеен (говоря между нами), потому что он – европейский проспект; всякий же европейский проспект есть не просто проспект, а (как я уже сказал) проспект европейский, потому что… да…
Потому что Невский Проспект – прямолинейный проспект.
Невский Проспект – немаловажный проспект в сем не русском – столичном – граде. Прочие русские города представляют собой деревянную кучу домишек.
И разительно от них всех отличается Петербург.
Если же вы продолжаете утверждать нелепейшую легенду – существование полуторамиллионного московского населения – то придется сознаться, что столицей будет Москва, ибо только в столицах бывает полуторамиллионное население; а в городах же губернских никакого полуторамиллионного населения нет, не бывало, не будет. И согласно нелепой легенде окажется, что столица не Петербург.
Если же Петербург не столица, то – нет Петербурга. Это только кажется, что он существует.
Как бы то ни было, Петербург не только нам кажется, но и оказывается – на картах: в виде двух друг в друге сидящих кружков с черной точкою в центре; и из этой вот математической точки, не имеющей измерения, заявляет он энергично о том, что он – есть: оттуда, из этой вот точки, несется потоком рой отпечатанной книги; несется из этой невидимой точки стремительно циркуляр.
"""

# %%
rake.run(normalize_text(fiction_text), minFrequency=2, maxWords=3)
# Out:
# [('русский империя наш', 8.666666666666666),
#  ('невский проспект', 4.34453781512605),
#  ('европейский проспект', 4.0588235294117645),
#  ('циркуляция публика', 3.666666666666667),
#  ('санкт-петербург', 3.4),
#  ('петербург', 1.4),
#  ('прочий', 1.0),
#  ('столичный', 1.0),
#  ('москва', 1.0),
#  ('питер', 1.0),
#  ('столица', 1.0),
#  ('кажется', 1.0),
#  ('…', 0)]

# %% [markdown]
# **TextRank** — алгоритм, основанный на PageRank, но для текстов и слов, а не документов и запросов.
#
# Совместная встречаемость описывается графом, веса ребер которого — частоты. Затем запускаем случайное блуждание по графу и смотрим, в какие вершины попадали чаще всего.
#
# *Подробнее в слайдах к лекции.*

# %%
from gensim.summarization import keywords as kw

# %%
help(kw)
# Out:
# Help on function keywords in module gensim.summarization.keywords:
#
# keywords(text, ratio=0.2, words=None, split=False, scores=False, pos_filter=('NN', 'JJ'), lemmatize=False, deacc=True)
#     Get most ranked words of provided text and/or its combinations.
#
#     Parameters
#     ----------
#
#     text : str
#         Input text.
#     ratio : float, optional
#         If no "words" option is selected, the number of sentences is reduced by the provided ratio,
#         else, the ratio is ignored.
#     words : int, optional
#         Number of returned words.
#     split : bool, optional
#         Whether split keywords if True.
#     scores : bool, optional
#         Whether score of keyword.
#     pos_filter : tuple, optional
#         Part of speech filters.
#     lemmatize : bool, optional
#         If True - lemmatize words.
#     deacc : bool, optional
#         If True - remove accentuation.
#
#     Returns
#     -------
#     result: list of (str, float)
#         If `scores`, keywords with scores **OR**
#     result: list of str
#         If `split`, keywords only **OR**
#     result: str
#         Keywords, joined by endl.

# %%
kw(normalize_text(fiction_text), pos_filter=[], scores=True)
# Out:
# [('что есть', 0.24696108869193048),
#  ('невскии проспект', 0.22861585354051184),
#  ('петербург', 0.20302072872045518),
#  ('дом', 0.18930951690594017),
#  ('точка', 0.16092189680762847),
#  ('град', 0.13868242582901555),
#  ('полуторамиллион', 0.12023442035578034),
#  ('быть', 0.11993619584882663),
#  ('или', 0.11953713983029073),
#  ('русскии империя наш', 0.11276916027375973),
#  ('как', 0.10223812274083775),
#  ('для', 0.09984082196962685),
#  ('город', 0.09897514503738426),
#  ('измерение', 0.098738381961809),
#  ('она', 0.09873838196180898),
#  ('например', 0.09873838196180815),
#  ('публика', 0.09713855498304028),
#  ('нелепыи', 0.09606330849487417),
#  ('столичныи', 0.09134216885015492),
#  ('принадлежать', 0.08994710459829743),
#  ('грузинскии', 0.08783160812587214),
#  ('польскии', 0.08783160812587208),
#  ('освещаться электричество', 0.08783160812587204),
#  ('малыи', 0.08783160812587161),
#  ('великии', 0.08783160812587154),
#  ('нестись', 0.08448253646738628),
#  ('сидеть', 0.08319622924559847)]

# %% [markdown]
# GenSim не фильтрует стоп-слова, но пытается внутри лемматизировать текст и приписать словам POS-теги.
# Для русского из коробки это не работает, но всегда можно отфильтровать именные группы, как сделано выше.

# %% [markdown]
# Другая библиотечка для суммаризации — **summa**. Она даже позволяет посмотреть на граф, по которому мы блуждаем.

# %%
#!pip3.7 install summa

# %%
from summa import keywords

# %%
help(keywords)
# Out:
# Help on module summa.keywords in summa:
#
# NAME
#     summa.keywords
#
# FUNCTIONS
#     get_graph(text, language='english', deaccent=False)
#
#     keywords(text, ratio=0.2, words=None, language='english', split=False, scores=False, deaccent=False, additional_stopwords=None)
#
# DATA
#     EXCLUDING_FILTER = []
#     INCLUDING_FILTER = ['NN', 'JJ']
#     WINDOW_SIZE = 2
#
# FILE
#     c:\users\lenovo\appdata\local\programs\python\python36\lib\site-packages\summa\keywords.py

# %%
keywords.keywords(normalize_text(wiki_text), additional_stopwords=stop, scores=True)
# Out:
# [('мальтийский язык', 0.35150225715348915),
#  ('например', 0.19823087780623316),
#  ('мальта', 0.16964534663801353),
#  ('арабский', 0.15249119743764813),
#  ('итальянский', 0.14958157229350344),
#  ('слово', 0.12823459233263615),
#  ('сравнить', 0.11923715387023573),
#  ('время', 0.1173920252238271),
#  ('официальный', 0.10309735449733748),
#  ('диалект', 0.10261276690390712),
#  ('семитский', 0.10201530518631918),
#  ('свой', 0.10155284672843584),
#  ('араб', 0.09810305765052496),
#  ('существительное', 0.0962487909409788),
#  ('однако', 0.09568262962465351),
#  ('население', 0.09556121533005192),
#  ('романский влияние', 0.09402415726944473),
#  ('происхождение', 0.09067692815374624),
#  ('также', 0.08986175312921905),
#  ('глагол', 0.08721969508185036),
#  ('использоваться', 0.08615123647975832),
#  ('форма', 0.08598815976193327),
#  ('год', 0.079241342272922),
#  ('английский', 0.0789200224584695),
#  ('римский', 0.07336816312327785),
#  ('мочь', 0.07033756348999641),
#  ('корень', 0.06812193361601),
#  ('новый', 0.06802882515664292),
#  ('италый', 0.06794338745183766),
#  ('это разговорный', 0.066882755332485),
#  ('лицо', 0.0664950303074863),
#  ('лексика', 0.06328401640914566),
#  ('сицилийский', 0.06194236916490586),
#  ('весь', 0.061842492909060603),
#  ('буква c', 0.05955788320496944),
#  ('должный', 0.059436781586978946),
#  ('святой', 0.05843481080148788),
#  ('соответствовать', 0.058162781382398124),
#  ('являться', 0.05772953184564938),
#  ('arte', 0.057035714610712926),
#  ('относиться', 0.05681593786073698),
#  ('заимствование', 0.056353049250039706),
#  ('искусство', 0.056188883234485405),
#  ('число', 0.05501587411970274),
#  ('администрация', 0.05384760377129935),
#  ('ʾal', 0.051763915441357465),
#  ('иврит', 0.05116891224733059),
#  ('множественный', 0.051103995823083975),
#  ('местный', 0.050855131627770764),
#  ('человек', 0.049450350079728415),
#  ('слог', 0.04921720842342551),
#  ('значительный', 0.04921720842342514),
#  ('латинский', 0.049217208423424925),
#  ('образоваться добавление', 0.048741877978695114),
#  ('литературный', 0.04848296228329742),
#  ('книга', 0.04818791362191202),
#  ('деятельность', 0.0476776047479175),
#  ('центр', 0.04766924146836045),
#  ('ес', 0.04698414113575891),
#  ('иметься', 0.046796402676322395),
#  ('суффикс', 0.0465735256309992),
#  ('век', 0.046523737806328035),
#  ('союз', 0.04615951460426076),
#  ('остров говорить', 0.0461254479343232),
#  ('э', 0.045907011275661345),
#  ('парламент', 0.04554159327080177),
#  ('поэма', 0.045481192138629355),
#  ('финикийский', 0.045034860494912295),
#  ('особенность', 0.04494511329818221),
#  ('англ', 0.04449032216279279),
#  ('письменный', 0.04427147147894717),
#  ('характеристика просодия', 0.04378023603892724),
#  ('день', 0.043655864513929866),
#  ('рука', 0.04328420293142305),
#  ('семито', 0.04240989755614076),
#  ('артикль', 0.04163884785656969),
#  ('отдельный', 0.04155243655834536),
#  ('писать', 0.041473699279035145),
#  ('сицилийско', 0.041266056223949174),
#  ('произойти', 0.040700336266948176),
#  ('некоторый', 0.04001549369787378),
#  ('гласный', 0.04000246256453209),
#  ('статус', 0.03984169942487103),
#  ('прилагательное', 0.03907502500523002),
#  ('sajf', 0.03905120671298088),
#  ('восточно', 0.03904909029157647),
#  ('византийский', 0.03904909029157625),
#  ('земля', 0.038654468496297854),
#  ('anton', 0.03833780069423869),
#  ('natura', 0.038337505074855366)]

# %%
G = keywords.get_graph(wiki_text)

# %%
help(G)
# Out:
# Help on Graph in module summa.graph object:
#
# class Graph(IGraph)
#  |  Implementation of an undirected graph, based on Pygraph
#  |
#  |  Method resolution order:
#  |      Graph
#  |      IGraph
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  add_edge(self, edge, wt=1, label='', attrs=[])
#  |      Add an edge to the graph connecting two nodes.
#  |
#  |      An edge, here, is a pair of nodes like C{(n, m)}.
#  |
#  |      @type  edge: tuple
#  |      @param edge: Edge.
#  |
#  |      @type  wt: number
#  |      @param wt: Edge weight.
#  |
#  |      @type  label: string
#  |      @param label: Edge label.
#  |
#  |      @type  attrs: list
#  |      @param attrs: List of node attributes specified as (attribute, value) tuples.
#  |
#  |  add_edge_attribute(self, edge, attr)
#  |
#  |  add_edge_attributes(self, edge, attrs)
#  |
#  |  add_node(self, node, attrs=None)
#  |      Add given node to the graph.
#  |
#  |      @attention: While nodes can be of any type, it's strongly recommended to use only
#  |      numbers and single-line strings as node identifiers if you intend to use write().
#  |
#  |      @type  node: node
#  |      @param node: Node identifier.
#  |
#  |      @type  attrs: list
#  |      @param attrs: List of node attributes specified as (attribute, value) tuples.
#  |
#  |  del_edge(self, edge)
#  |
#  |  del_edge_labeling(self, edge)
#  |
#  |  del_node(self, node)
#  |      Remove a node from the graph.
#  |
#  |      @type  node: node
#  |      @param node: Node identifier.
#  |
#  |  edge_attributes(self, edge)
#  |
#  |  edge_weight(self, edge)
#  |      Get the weight of an edge.
#  |
#  |      @type  edge: edge
#  |      @param edge: One edge.
#  |
#  |      @rtype:  number
#  |      @return: Edge weight.
#  |
#  |  edges(self)
#  |      Return all edges in the graph.
#  |
#  |      @rtype:  list
#  |      @return: List of all edges in the graph.
#  |
#  |  get_edge_properties(self, edge)
#  |      # Helper methods
#  |
#  |  has_edge(self, edge)
#  |      Return whether an edge exists.
#  |
#  |      @type  edge: tuple
#  |      @param edge: Edge.
#  |
#  |      @rtype:  boolean
#  |      @return: Truth-value for edge existence.
#  |
#  |  has_node(self, node)
#  |      Return whether the requested node exists.
#  |
#  |      @type  node: node
#  |      @param node: Node identifier
#  |
#  |      @rtype:  boolean
#  |      @return: Truth-value for node existence.
#  |
#  |  neighbors(self, node)
#  |      Return all nodes that are directly accessible from given node.
#  |
#  |      @type  node: node
#  |      @param node: Node identifier
#  |
#  |      @rtype:  list
#  |      @return: List of nodes directly accessible from given node.
#  |
#  |  nodes(self)
#  |      Return node list.
#  |
#  |      @rtype:  list
#  |      @return: Node list.
#  |
#  |  set_edge_properties(self, edge, **properties)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  DEFAULT_LABEL = ''
#  |
#  |  DEFAULT_WEIGHT = 0
#  |
#  |  LABEL_ATTRIBUTE_NAME = 'label'
#  |
#  |  WEIGHT_ATTRIBUTE_NAME = 'weight'
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from IGraph:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
for edge in G.edges():
    print(edge, G.edge_weight(edge))
# Out:
# ('мальтийский', 'язык') 1
# ('язык', 'мальтийский') 1
# ('собств', 'язык') 1
# ('язык', 'собств') 1
# ('наименование', 'собств') 1
# ('собств', 'наименование') 1
# ('malti', 'наименование') 1
# ('наименование', 'malti') 1
# ('язык', 'malti') 1
# ('malti', 'язык') 1
# ('мальтийцев', 'язык') 1
# ('язык', 'мальтийцев') 1
# ('официальный', 'мальтийцев') 1
# ('мальтийцев', 'официальный') 1
# ('язык', 'официальный') 1
# ('официальный', 'язык') 1
# ('республики', 'язык') 1
# ('язык', 'республики') 1
# ('мальта', 'республики') 1
# ('республики', 'мальта') 1
# ('наряду', 'мальта') 1
# ('мальта', 'наряду') 1
# ('с', 'наряду') 1
# ('наряду', 'с') 1
# ('английским', 'с') 1
# ('с', 'английским') 1
# ('один', 'английским') 1
# ('английским', 'один') 1
# ('из', 'один') 1
# ('один', 'из') 1
# ('официальных', 'из') 1
# ('из', 'официальных') 1
# ('языков', 'официальных') 1
# ('официальных', 'языков') 1
# ('европейского', 'языков') 1
# ('языков', 'европейского') 1
# ('союза', 'европейского') 1
# ('европейского', 'союза') 1
# ('относится', 'союза') 1
# ('союза', 'относится') 1
# ('к', 'относится') 1
# ('относится', 'к') 1
# ('семитской', 'к') 1
# ('к', 'семитской') 1
# ('семье', 'семитской') 1
# ('семитской', 'семье') 1
# ('афразийской', 'семье') 1
# ('семье', 'афразийской') 1
# ('семито', 'афразийской') 1
# ('афразийской', 'семито') 1
# ('хамитской', 'семито') 1
# ('семито', 'хамитской') 1
# ('макросемьи', 'хамитской') 1
# ('хамитской', 'макросемьи') 1
# ('языков', 'макросемьи') 1
# ('макросемьи', 'языков') 1
# ('язык', 'языков') 1
# ('языков', 'язык') 1
# ('близок', 'язык') 1
# ('язык', 'близок') 1
# ('к', 'близок') 1
# ('близок', 'к') 1
# ('арабскому', 'к') 1
# ('к', 'арабскому') 1
# ('особенно', 'арабскому') 1
# ('арабскому', 'особенно') 1
# ('к', 'особенно') 1
# ('особенно', 'к') 1
# ('его', 'к') 1
# ('к', 'его') 1
# ('магрибскому', 'его') 1
# ('его', 'магрибскому') 1
# ('диалекту', 'магрибскому') 1
# ('магрибскому', 'диалекту') 1
# ('однако', 'диалекту') 1
# ('диалекту', 'однако') 1
# ('в', 'однако') 1
# ('однако', 'в') 1
# ('настоящее', 'в') 1
# ('в', 'настоящее') 1
# ('время', 'настоящее') 1
# ('настоящее', 'время') 1
# ('считается', 'время') 1
# ('время', 'считается') 1
# ('отдельным', 'считается') 1
# ('считается', 'отдельным') 1
# ('языком', 'отдельным') 1
# ('отдельным', 'языком') 1
# ('со', 'языком') 1
# ('языком', 'со') 1
# ('своими', 'со') 1
# ('со', 'своими') 1
# ('синтаксическими', 'своими') 1
# ('своими', 'синтаксическими') 1
# ('фонетическими', 'синтаксическими') 1
# ('синтаксическими', 'фонетическими') 1
# ('и', 'фонетическими') 1
# ('фонетическими', 'и') 1
# ('лексическими', 'и') 1
# ('и', 'лексическими') 1
# ('особенностями', 'лексическими') 1
# ('лексическими', 'особенностями') 1
# ('лингвогеография', 'особенностями') 1
# ('особенностями', 'лингвогеография') 1
# ('число', 'лингвогеография') 1
# ('лингвогеография', 'число') 1
# ('говорящих', 'число') 1
# ('число', 'говорящих') 1
# ('тыс', 'говорящих') 1
# ('говорящих', 'тыс') 1
# ('чел', 'тыс') 1
# ('тыс', 'чел') 1
# ('статус', 'чел') 1
# ('чел', 'статус') 1
# ('мальтийского', 'статус') 1
# ('статус', 'мальтийского') 1
# ('языка', 'мальтийского') 1
# ('мальтийского', 'языка') 1
# ('определяется', 'языка') 1
# ('языка', 'определяется') 1
# ('в', 'определяется') 1
# ('определяется', 'в') 1
# ('статье', 'в') 1
# ('в', 'статье') 1
# ('главы', 'статье') 1
# ('статье', 'главы') 1
# ('мальты', 'конституции') 1
# ('конституции', 'мальты') 1
# ('национальным', 'мальты') 1
# ('мальты', 'национальным') 1
# ('языком', 'национальным') 1
# ('национальным', 'языком') 1
# ('мальты', 'языком') 1
# ('языком', 'мальты') 1
# ('является', 'мальты') 1
# ('мальты', 'является') 1
# ('мальтийский', 'является') 1
# ('является', 'мальтийский') 1
# ('мальтийский', 'мальтийский') 1
# ('и', 'мальтийский') 1
# ('мальтийский', 'и') 1
# ('английский', 'и') 1
# ('и', 'английский') 1
# ('языки', 'английский') 1
# ('английский', 'языки') 1
# ('а', 'языки') 1
# ('языки', 'а') 1
# ('также', 'а') 1
# ('а', 'также') 1
# ('и', 'также') 1
# ('также', 'и') 1
# ('другой', 'и') 1
# ('и', 'другой') 1
# ('язык', 'другой') 1
# ('другой', 'язык') 1
# ('который', 'язык') 1
# ('язык', 'который') 1
# ('может', 'который') 1
# ('который', 'может') 1
# ('быть', 'может') 1
# ('может', 'быть') 1
# ('утверждён', 'быть') 1
# ('быть', 'утверждён') 1
# ('парламентом', 'утверждён') 1
# ('утверждён', 'парламентом') 1
# ('по', 'парламентом') 1
# ('парламентом', 'по') 1
# ('закону', 'по') 1
# ('по', 'закону') 1
# ('одобренному', 'закону') 1
# ('закону', 'одобренному') 1
# ('не', 'одобренному') 1
# ('одобренному', 'не') 1
# ('менее', 'не') 1
# ('не', 'менее') 1
# ('чем', 'менее') 1
# ('менее', 'чем') 1
# ('всех', 'чем') 1
# ('чем', 'всех') 1
# ('членов', 'всех') 1
# ('всех', 'членов') 1
# ('палаты', 'членов') 1
# ('членов', 'палаты') 1
# ('представителей', 'палаты') 1
# ('палаты', 'представителей') 1
# ('должны', 'представителей') 1
# ('представителей', 'должны') 1
# ('быть', 'должны') 1
# ('должны', 'быть') 1
# ('официальными', 'быть') 1
# ('быть', 'официальными') 1
# ('языками', 'официальными') 1
# ('официальными', 'языками') 1
# ('мальты', 'языками') 1
# ('языками', 'мальты') 1
# ('и', 'мальты') 1
# ('мальты', 'и') 1
# ('администрация', 'и') 1
# ('и', 'администрация') 1
# ('может', 'администрация') 1
# ('администрация', 'может') 1
# ('использовать', 'может') 1
# ('может', 'использовать') 1
# ('во', 'использовать') 1
# ('использовать', 'во') 1
# ('всех', 'во') 1
# ('во', 'всех') 1
# ('своих', 'всех') 1
# ('всех', 'своих') 1
# ('официальных', 'своих') 1
# ('своих', 'официальных') 1
# ('целях', 'официальных') 1
# ('официальных', 'целях') 1
# ('любой', 'целях') 1
# ('целях', 'любой') 1
# ('из', 'любой') 1
# ('любой', 'из') 1
# ('этих', 'из') 1
# ('из', 'этих') 1
# ('языков', 'этих') 1
# ('этих', 'языков') 1
# ('при', 'языков') 1
# ('языков', 'при') 1
# ('условии', 'при') 1
# ('при', 'условии') 1
# ('что', 'условии') 1
# ('условии', 'что') 1
# ('любое', 'что') 1
# ('что', 'любое') 1
# ('лицо', 'любое') 1
# ('любое', 'лицо') 1
# ('вправе', 'лицо') 1
# ('лицо', 'вправе') 1
# ('обратиться', 'вправе') 1
# ('вправе', 'обратиться') 1
# ('к', 'обратиться') 1
# ('обратиться', 'к') 1
# ('администрации', 'к') 1
# ('к', 'администрации') 1
# ('на', 'администрации') 1
# ('администрации', 'на') 1
# ('любом', 'на') 1
# ('на', 'любом') 1
# ('из', 'любом') 1
# ('любом', 'из') 1
# ('и', 'языков') 1
# ('языков', 'и') 1
# ('ответ', 'и') 1
# ('и', 'ответ') 1
# ('администрации', 'ответ') 1
# ('ответ', 'администрации') 1
# ('данному', 'администрации') 1
# ('администрации', 'данному') 1
# ('лицу', 'данному') 1
# ('данному', 'лицу') 1
# ('должен', 'лицу') 1
# ('лицу', 'должен') 1
# ('быть', 'должен') 1
# ('должен', 'быть') 1
# ('дан', 'быть') 1
# ('быть', 'дан') 1
# ('на', 'дан') 1
# ('дан', 'на') 1
# ('том', 'на') 1
# ('на', 'том') 1
# ('же', 'том') 1
# ('том', 'же') 1
# ('языке', 'же') 1
# ('же', 'языке') 1
# ('языком', 'языке') 1
# ('языке', 'языком') 1
# ('судопроизводства', 'языком') 1
# ('языком', 'судопроизводства') 1
# ('должен', 'судопроизводства') 1
# ('судопроизводства', 'должен') 1
# ('мальтийский', 'быть') 1
# ('быть', 'мальтийский') 1
# ('при', 'мальтийский') 1
# ('мальтийский', 'при') 1
# ('парламент', 'что') 1
# ('что', 'парламент') 1
# ('может', 'парламент') 1
# ('парламент', 'может') 1
# ('издать', 'может') 1
# ('может', 'издать') 1
# ('постановление', 'издать') 1
# ('издать', 'постановление') 1
# ('об', 'постановление') 1
# ('постановление', 'об') 1
# ('использовании', 'об') 1
# ('об', 'использовании') 1
# ('английского', 'использовании') 1
# ('использовании', 'английского') 1
# ('языка', 'английского') 1
# ('английского', 'языка') 1
# ('в', 'языка') 1
# ('языка', 'в') 1
# ('случаях', 'в') 1
# ('в', 'случаях') 1
# ('и', 'случаях') 1
# ('случаях', 'и') 1
# ('на', 'и') 1
# ('и', 'на') 1
# ('условиях', 'на') 1
# ('на', 'условиях') 1
# ('определяемых', 'условиях') 1
# ('условиях', 'определяемых') 1
# ('в', 'определяемых') 1
# ('определяемых', 'в') 1
# ('данном', 'в') 1
# ('в', 'данном') 1
# ('постановлении', 'данном') 1
# ('данном', 'постановлении') 1
# ('палата', 'постановлении') 1
# ('постановлении', 'палата') 1
# ('представителей', 'палата') 1
# ('палата', 'представителей') 1
# ('может', 'представителей') 1
# ('представителей', 'может') 1
# ('регулируя', 'может') 1
# ('может', 'регулируя') 1
# ('свои', 'регулируя') 1
# ('регулируя', 'свои') 1
# ('собственные', 'свои') 1
# ('свои', 'собственные') 1
# ('процессуальные', 'собственные') 1
# ('собственные', 'процессуальные') 1
# ('нормы', 'процессуальные') 1
# ('процессуальные', 'нормы') 1
# ('определить', 'нормы') 1
# ('нормы', 'определить') 1
# ('язык', 'определить') 1
# ('определить', 'язык') 1
# ('или', 'язык') 1
# ('язык', 'или') 1
# ('языки', 'или') 1
# ('или', 'языки') 1
# ('которые', 'языки') 1
# ('языки', 'которые') 1
# ('должны', 'которые') 1
# ('которые', 'должны') 1
# ('использоваться', 'должны') 1
# ('должны', 'использоваться') 1
# ('в', 'использоваться') 1
# ('использоваться', 'в') 1
# ('работе', 'в') 1
# ('в', 'работе') 1
# ('парламента', 'работе') 1
# ('работе', 'парламента') 1
# ('и', 'парламента') 1
# ('парламента', 'и') 1
# ('в', 'и') 1
# ('и', 'в') 1
# ('протоколировании', 'в') 1
# ('в', 'протоколировании') 1
# ('большинство', 'протоколировании') 1
# ('протоколировании', 'большинство') 1
# ('населения', 'большинство') 1
# ('большинство', 'населения') 1
# ('мальты', 'населения') 1
# ('населения', 'мальты') 1
# ('двуязычно', 'мальты') 1
# ('мальты', 'двуязычно') 1
# ('мальтийский', 'двуязычно') 1
# ('двуязычно', 'мальтийский') 1
# ('используется', 'язык') 1
# ('язык', 'используется') 1
# ('в', 'используется') 1
# ('используется', 'в') 1
# ('повседневном', 'в') 1
# ('в', 'повседневном') 1
# ('общении', 'повседневном') 1
# ('повседневном', 'общении') 1
# ('в', 'общении') 1
# ('общении', 'в') 1
# ('парламенте', 'в') 1
# ('в', 'парламенте') 1
# ('церкви', 'в') 1
# ('в', 'церкви') 1
# ('сми', 'в') 1
# ('в', 'сми') 1
# ('интернете', 'в') 1
# ('в', 'интернете') 1
# ('разговоре', 'в') 1
# ('в', 'разговоре') 1
# ('мальтийский', 'разговоре') 1
# ('разговоре', 'мальтийский') 1
# ('часто', 'мальтийский') 1
# ('мальтийский', 'часто') 1
# ('смешивается', 'часто') 1
# ('часто', 'смешивается') 1
# ('с', 'смешивается') 1
# ('смешивается', 'с') 1
# ('на', 'английским') 1
# ('английским', 'на') 1
# ('мальтийский', 'на') 1
# ('на', 'мальтийский') 1
# ('как', 'мальтийский') 1
# ('мальтийский', 'как') 1
# ('на', 'как') 1
# ('как', 'на') 1
# ('официальный', 'на') 1
# ('на', 'официальный') 1
# ('ес', 'язык') 1
# ('язык', 'ес') 1
# ('должны', 'ес') 1
# ('ес', 'должны') 1
# ('переводиться', 'должны') 1
# ('должны', 'переводиться') 1
# ('все', 'переводиться') 1
# ('переводиться', 'все') 1
# ('официальные', 'все') 1
# ('все', 'официальные') 1
# ('документы', 'официальные') 1
# ('официальные', 'документы') 1
# ('ес', 'документы') 1
# ('документы', 'ес') 1
# ('в', 'ес') 1
# ('ес', 'в') 1
# ('существует', 'интернете') 1
# ('интернете', 'существует') 1
# ('мальтийская', 'существует') 1
# ('существует', 'мальтийская') 1
# ('версия', 'мальтийская') 1
# ('мальтийская', 'версия') 1
# ('портала', 'версия') 1
# ('версия', 'портала') 1
# ('европейского', 'портала') 1
# ('портала', 'европейского') 1
# ('на', 'союза') 1
# ('союза', 'на') 1
# ('мальтийском', 'на') 1
# ('на', 'мальтийском') 1
# ('языке', 'мальтийском') 1
# ('мальтийском', 'языке') 1
# ('также', 'языке') 1
# ('языке', 'также') 1
# ('говорят', 'также') 1
# ('также', 'говорят') 1
# ('в', 'говорят') 1
# ('говорят', 'в') 1
# ('австралии', 'в') 1
# ('в', 'австралии') 1
# ('среде', 'в') 1
# ('в', 'среде') 1
# ('выходцев', 'среде') 1
# ('среде', 'выходцев') 1
# ('из', 'выходцев') 1
# ('выходцев', 'из') 1
# ('мальты', 'из') 1
# ('из', 'мальты') 1
# ('их', 'и') 1
# ('и', 'их') 1
# ('потомков', 'их') 1
# ('их', 'потомков') 1
# ('у', 'потомков') 1
# ('потомков', 'у') 1
# ('них', 'у') 1
# ('у', 'них') 1
# ('сложился', 'них') 1
# ('них', 'сложился') 1
# ('свой', 'сложился') 1
# ('сложился', 'свой') 1
# ('диалект', 'свой') 1
# ('свой', 'диалект') 1
# ('maltraljan', 'диалект') 1
# ('диалект', 'maltraljan') 1
# ('maltes', 'maltraljan') 1
# ('maltraljan', 'maltes') 1
# ('australian', 'maltes') 1
# ('maltes', 'australian') 1
# ('история', 'australian') 1
# ('australian', 'история') 1
# ('во', 'история') 1
# ('история', 'во') 1
# ('время', 'во') 1
# ('во', 'время') 1
# ('финикийской', 'время') 1
# ('время', 'финикийской') 1
# ('позже', 'финикийской') 1
# ('финикийской', 'позже') 1
# ('карфагенской', 'позже') 1
# ('позже', 'карфагенской') 1
# ('колонизации', 'карфагенской') 1
# ('карфагенской', 'колонизации') 1
# ('до', 'колонизации') 1
# ('колонизации', 'до') 1
# ('н', 'до') 1
# ('до', 'н') 1
# ('э', 'н') 1
# ('н', 'э') 1
# ('до', 'э') 1
# ('э', 'до') 1
# ('население', 'э') 1
# ('э', 'население') 1
# ('мальтийских', 'население') 1
# ('население', 'мальтийских') 1
# ('островов', 'мальтийских') 1
# ('мальтийских', 'островов') 1
# ('говорило', 'островов') 1
# ('островов', 'говорило') 1
# ('на', 'говорило') 1
# ('говорило', 'на') 1
# ('одном', 'на') 1
# ('на', 'одном') 1
# ('из', 'одном') 1
# ('одном', 'из') 1
# ('финикийских', 'из') 1
# ('из', 'финикийских') 1
# ('пунических', 'финикийских') 1
# ('финикийских', 'пунических') 1
# ('языков', 'пунических') 1
# ('пунических', 'языков') 1
# ('на', 'языков') 1
# ('языков', 'на') 1
# ('финикийском', 'на') 1
# ('на', 'финикийском') 1
# ('наречии', 'финикийском') 1
# ('финикийском', 'наречии') 1
# ('продолжали', 'наречии') 1
# ('наречии', 'продолжали') 1
# ('говорить', 'продолжали') 1
# ('продолжали', 'говорить') 1
# ('также', 'говорить') 1
# ('говорить', 'также') 1
# ('в', 'также') 1
# ('также', 'в') 1
# ('период', 'в') 1
# ('в', 'период') 1
# ('римского', 'период') 1
# ('период', 'римского') 1
# ('с', 'римского') 1
# ('римского', 'с') 1
# ('до', 'с') 1
# ('с', 'до') 1
# ('а', 'э') 1
# ('э', 'а') 1
# ('после', 'а') 1
# ('а', 'после') 1
# ('разделения', 'после') 1
# ('после', 'разделения') 1
# ('империи', 'разделения') 1
# ('разделения', 'империи') 1
# ('на', 'империи') 1
# ('империи', 'на') 1
# ('западную', 'на') 1
# ('на', 'западную') 1
# ('и', 'западную') 1
# ('западную', 'и') 1
# ('восточную', 'и') 1
# ('и', 'восточную') 1
# ('восточно', 'восточную') 1
# ('восточную', 'восточно') 1
# ('римского', 'восточно') 1
# ('восточно', 'римского') 1
# ('византийского', 'римского') 1
# ('римского', 'византийского') 1
# ('владычества', 'византийского') 1
# ('византийского', 'владычества') 1
# ('в', 'владычества') 1
# ('владычества', 'в') 1
# ('н', 'в') 1
# ('в', 'н') 1
# ('в', 'э') 1
# ('э', 'в') 1
# ('году', 'в') 1
# ('в', 'году') 1
# ('острова', 'году') 1
# ('году', 'острова') 1
# ('были', 'острова') 1
# ('острова', 'были') 1
# ('завоёваны', 'были') 1
# ('были', 'завоёваны') 1
# ('арабами', 'завоёваны') 1
# ('завоёваны', 'арабами') 1
# ('арабский', 'арабами') 1
# ('арабами', 'арабский') 1
# ('язык', 'арабский') 1
# ('арабский', 'язык') 1
# ('распространился', 'язык') 1
# ('язык', 'распространился') 1
# ('и', 'распространился') 1
# ('распространился', 'и') 1
# ('среди', 'и') 1
# ('и', 'среди') 1
# ('коренного', 'среди') 1
# ('среди', 'коренного') 1
# ('населения', 'коренного') 1
# ('коренного', 'населения') 1
# ('в', 'населения') 1
# ('населения', 'в') 1
# ('частности', 'в') 1
# ('в', 'частности') 1
# ('благодаря', 'частности') 1
# ('частности', 'благодаря') 1
# ('своему', 'благодаря') 1
# ('благодаря', 'своему') 1
# ('родству', 'своему') 1
# ('своему', 'родству') 1
# ('с', 'родству') 1
# ('родству', 'с') 1
# ('финикийским', 'с') 1
# ('с', 'финикийским') 1
# ('при', 'финикийским') 1
# ('финикийским', 'при') 1
# ('этом', 'при') 1
# ('при', 'этом') 1
# ('разговорная', 'этом') 1
# ('этом', 'разговорная') 1
# ('речь', 'разговорная') 1
# ('разговорная', 'речь') 1
# ('арабов', 'речь') 1
# ('речь', 'арабов') 1
# ('и', 'арабов') 1
# ('арабов', 'и') 1
# ('соответственно', 'и') 1
# ('и', 'соответственно') 1
# ('местного', 'соответственно') 1
# ('соответственно', 'местного') 1
# ('населения', 'местного') 1
# ('местного', 'населения') 1
# ('отличалась', 'населения') 1
# ('населения', 'отличалась') 1
# ('от', 'отличалась') 1
# ('отличалась', 'от') 1
# ('классического', 'от') 1
# ('от', 'классического') 1
# ('письменного', 'классического') 1
# ('классического', 'письменного') 1
# ('арабского', 'письменного') 1
# ('письменного', 'арабского') 1
# ('в', 'арабского') 1
# ('арабского', 'в') 1
# ('этот', 'в') 1
# ('в', 'этот') 1
# ('период', 'этот') 1
# ('этот', 'период') 1
# ('можно', 'период') 1
# ('период', 'можно') 1
# ('говорить', 'можно') 1
# ('можно', 'говорить') 1
# ('о', 'говорить') 1
# ('говорить', 'о') 1
# ('существовании', 'о') 1
# ('о', 'существовании') 1
# ('двух', 'существовании') 1
# ('существовании', 'двух') 1
# ('диалектов', 'двух') 1
# ('двух', 'диалектов') 1
# ('классический', 'диалектов') 1
# ('диалектов', 'классический') 1
# ('арабский', 'классический') 1
# ('классический', 'арабский') 1
# ('письменный', 'арабский') 1
# ('арабский', 'письменный') 1
# ('язык', 'письменный') 1
# ('письменный', 'язык') 1
# ('и', 'язык') 1
# ('язык', 'и') 1
# ('сицилийско', 'и') 1
# ('и', 'сицилийско') 1
# ('арабский', 'сицилийско') 1
# ('сицилийско', 'арабский') 1
# ('народно', 'арабский') 1
# ('арабский', 'народно') 1
# ('разговорный', 'народно') 1
# ('народно', 'разговорный') 1
# ('язык', 'разговорный') 1
# ('разговорный', 'язык') 1
# ('центром', 'язык') 1
# ('язык', 'центром') 1
# ('распространения', 'центром') 1
# ('центром', 'распространения') 1
# ('которого', 'распространения') 1
# ('распространения', 'которого') 1
# ('стал', 'которого') 1
# ('которого', 'стал') 1
# ('сицилийский', 'стал') 1
# ('стал', 'сицилийский') 1
# ('эмират', 'сицилийский') 1
# ('сицилийский', 'эмират') 1
# ('после', 'эмират') 1
# ('эмират', 'после') 1
# ('вторжения', 'после') 1
# ('после', 'вторжения') 1
# ('норманнов', 'вторжения') 1
# ('вторжения', 'норманнов') 1
# ('сицилийско', 'норманнов') 1
# ('норманнов', 'сицилийско') 1
# ('был', 'язык') 1
# ('язык', 'был') 1
# ('постепенно', 'был') 1
# ('был', 'постепенно') 1
# ('вытеснен', 'постепенно') 1
# ('постепенно', 'вытеснен') 1
# ('с', 'вытеснен') 1
# ('вытеснен', 'с') 1
# ('сицилии', 'с') 1
# ('с', 'сицилии') 1
# ('однако', 'сицилии') 1
# ('сицилии', 'однако') 1
# ('он', 'однако') 1
# ('однако', 'он') 1
# ('сохранился', 'он') 1
# ('он', 'сохранился') 1
# ('на', 'сохранился') 1
# ('сохранился', 'на') 1
# ('небольшом', 'на') 1
# ('на', 'небольшом') 1
# ('периферийном', 'небольшом') 1
# ('небольшом', 'периферийном') 1
# ('острове', 'периферийном') 1
# ('периферийном', 'острове') 1
# ('мальта', 'острове') 1
# ('острове', 'мальта') 1
# ('хотя', 'мальта') 1
# ('мальта', 'хотя') 1
# ('и', 'хотя') 1
# ('хотя', 'и') 1
# ('испытал', 'и') 1
# ('и', 'испытал') 1
# ('на', 'испытал') 1
# ('испытал', 'на') 1
# ('себе', 'на') 1
# ('на', 'себе') 1
# ('сильное', 'себе') 1
# ('себе', 'сильное') 1
# ('романское', 'сильное') 1
# ('сильное', 'романское') 1
# ('влияние', 'романское') 1
# ('романское', 'влияние') 1
# ('именно', 'влияние') 1
# ('влияние', 'именно') 1
# ('от', 'именно') 1
# ('именно', 'от') 1
# ('него', 'от') 1
# ('от', 'него') 1
# ('и', 'него') 1
# ('него', 'и') 1
# ('происходит', 'и') 1
# ('и', 'происходит') 1
# ('нынешний', 'происходит') 1
# ('происходит', 'нынешний') 1
# ('мальтийский', 'нынешний') 1
# ('нынешний', 'мальтийский') 1
# ('новый', 'язык') 1
# ('язык', 'новый') 1
# ('этап', 'новый') 1
# ('новый', 'этап') 1
# ('начался', 'этап') 1
# ('этап', 'начался') 1
# ('с', 'начался') 1
# ('начался', 'с') 1
# ('норманнским', 'с') 1
# ('с', 'норманнским') 1
# ('завоеванием', 'норманнским') 1
# ('норманнским', 'завоеванием') 1
# ('мальты', 'завоеванием') 1
# ('завоеванием', 'мальты') 1
# ('в', 'мальты') 1
# ('мальты', 'в') 1
# ('и', 'году') 1
# ('году', 'и') 1
# ('присоединением', 'и') 1
# ('и', 'присоединением') 1
# ('её', 'присоединением') 1
# ('присоединением', 'её') 1
# ('к', 'её') 1
# ('её', 'к') 1
# ('сицилии', 'к') 1
# ('к', 'сицилии') 1
# ('язык', 'сицилии') 1
# ('сицилии', 'язык') 1
# ('администрации', 'язык') 1
# ('язык', 'администрации') 1
# ('относился', 'администрации') 1
# ('администрации', 'относился') 1
# ('к', 'относился') 1
# ('относился', 'к') 1
# ('романским', 'к') 1
# ('к', 'романским') 1
# ('и', 'романским') 1
# ('романским', 'и') 1
# ('это', 'в') 1
# ('в', 'это') 1
# ('время', 'это') 1
# ('это', 'время') 1
# ('произошёл', 'время') 1
# ('время', 'произошёл') 1
# ('новый', 'произошёл') 1
# ('произошёл', 'новый') 1
# ('языковой', 'новый') 1
# ('новый', 'языковой') 1
# ('семито', 'языковой') 1
# ('языковой', 'семито') 1
# ('романский', 'семито') 1
# ('семито', 'романский') 1
# ('контакт', 'романский') 1
# ('романский', 'контакт') 1
# ('полной', 'контакт') 1
# ('контакт', 'полной') 1
# ('романизации', 'полной') 1
# ('полной', 'романизации') 1
# ('населения', 'романизации') 1
# ('романизации', 'населения') 1
# ('как', 'населения') 1
# ('населения', 'как') 1
# ('и', 'как') 1
# ('как', 'и') 1
# ('римскую', 'в') 1
# ('в', 'римскую') 1
# ('эпоху', 'римскую') 1
# ('римскую', 'эпоху') 1
# ('не', 'эпоху') 1
# ('эпоху', 'не') 1
# ('произошло', 'не') 1
# ('не', 'произошло') 1
# ('так', 'произошло') 1
# ('произошло', 'так') 1
# ('как', 'так') 1
# ('так', 'как') 1
# ('арабы', 'как') 1
# ('как', 'арабы') 1
# ('продолжительное', 'арабы') 1
# ('арабы', 'продолжительное') 1
# ('время', 'продолжительное') 1
# ('продолжительное', 'время') 1
# ('оставались', 'время') 1
# ('время', 'оставались') 1
# ('на', 'оставались') 1
# ('оставались', 'на') 1
# ('островах', 'на') 1
# ('на', 'островах') 1
# ('и', 'островах') 1
# ('островах', 'и') 1
# ('оказывали', 'и') 1
# ('и', 'оказывали') 1
# ('значительное', 'оказывали') 1
# ('оказывали', 'значительное') 1
# ('культурное', 'значительное') 1
# ('значительное', 'культурное') 1
# ('и', 'культурное') 1
# ('культурное', 'и') 1
# ('языковое', 'и') 1
# ('и', 'языковое') 1
# ('влияние', 'языковое') 1
# ('языковое', 'влияние') 1
# ('однако', 'влияние') 1
# ('влияние', 'однако') 1
# ('уже', 'однако') 1
# ('однако', 'уже') 1
# ('тогда', 'уже') 1
# ('уже', 'тогда') 1
# ('в', 'тогда') 1
# ('тогда', 'в') 1
# ('язык', 'в') 1
# ('в', 'язык') 1
# ('попали', 'язык') 1
# ('язык', 'попали') 1
# ('первые', 'попали') 1
# ('попали', 'первые') 1
# ('романские', 'первые') 1
# ('первые', 'романские') 1
# ('заимствования', 'романские') 1
# ('романские', 'заимствования') 1
# ('арабы', 'заимствования') 1
# ('заимствования', 'арабы') 1
# ('покинули', 'арабы') 1
# ('арабы', 'покинули') 1
# ('мальту', 'покинули') 1
# ('покинули', 'мальту') 1
# ('через', 'мальту') 1
# ('мальту', 'через') 1
# ('лет', 'через') 1
# ('через', 'лет') 1
# ('и', 'лет') 1
# ('лет', 'и') 1
# ('вследствие', 'и') 1
# ('и', 'вследствие') 1
# ('этого', 'вследствие') 1
# ('вследствие', 'этого') 1
# ('произошло', 'этого') 1
# ('этого', 'произошло') 1
# ('размежевание', 'произошло') 1
# ('произошло', 'размежевание') 1
# ('мальтийского', 'размежевание') 1
# ('размежевание', 'мальтийского') 1
# ('и', 'мальтийского') 1
# ('мальтийского', 'и') 1
# ('арабского', 'и') 1
# ('и', 'арабского') 1
# ('мальта', 'арабского') 1
# ('арабского', 'мальта') 1
# ('была', 'мальта') 1
# ('мальта', 'была') 1
# ('связана', 'была') 1
# ('была', 'связана') 1
# ('с', 'связана') 1
# ('связана', 'с') 1
# ('сицилией', 'с') 1
# ('с', 'сицилией') 1
# ('на', 'сицилией') 1
# ('сицилией', 'на') 1
# ('протяжении', 'на') 1
# ('на', 'протяжении') 1
# ('лет', 'протяжении') 1
# ('протяжении', 'лет') 1
# ('переходила', 'лет') 1
# ('лет', 'переходила') 1
# ('вместе', 'переходила') 1
# ('переходила', 'вместе') 1
# ('с', 'вместе') 1
# ('вместе', 'с') 1
# ('ней', 'с') 1
# ('с', 'ней') 1
# ('от', 'ней') 1
# ('ней', 'от') 1
# ('одной', 'от') 1
# ('от', 'одной') 1
# ('феодальной', 'одной') 1
# ('одной', 'феодальной') 1
# ('юрисдикции', 'феодальной') 1
# ('феодальной', 'юрисдикции') 1
# ('к', 'юрисдикции') 1
# ('юрисдикции', 'к') 1
# ('другой', 'к') 1
# ('к', 'другой') 1
# ('течение', 'в') 1
# ('в', 'течение') 1
# ('этого', 'течение') 1
# ('течение', 'этого') 1
# ('времени', 'этого') 1
# ('этого', 'времени') 1
# ('количество', 'времени') 1
# ('времени', 'количество') 1
# ('романских', 'количество') 1
# ('количество', 'романских') 1
# ('заимствований', 'романских') 1
# ('романских', 'заимствований') 1
# ('увеличивалось', 'заимствований') 1
# ('заимствований', 'увеличивалось') 1
# ('к', 'увеличивалось') 1
# ('увеличивалось', 'к') 1
# ('xv', 'к') 1
# ('к', 'xv') 1
# ('веку', 'xv') 1
# ('xv', 'веку') 1
# ('относится', 'веку') 1
# ('веку', 'относится') 1
# ('первый', 'относится') 1
# ('относится', 'первый') 1
# ('известный', 'первый') 1
# ('первый', 'известный') 1
# ('литературный', 'известный') 1
# ('известный', 'литературный') 1
# ('текст', 'литературный') 1
# ('литературный', 'текст') 1
# ('на', 'текст') 1
# ('текст', 'на') 1
# ('поэма', 'языке') 1
# ('языке', 'поэма') 1
# ('il', 'поэма') 1
# ('поэма', 'il') 1
# ('cantilena', 'il') 1
# ('il', 'cantilena') 1
# ('наиболее', 'cantilena') 1
# ('cantilena', 'наиболее') 1
# ('сильное', 'наиболее') 1
# ('наиболее', 'сильное') 1
# ('воздействие', 'романское') 1
# ('романское', 'воздействие') 1
# ('язык', 'воздействие') 1
# ('воздействие', 'язык') 1
# ('получил', 'язык') 1
# ('язык', 'получил') 1
# ('во', 'получил') 1
# ('получил', 'во') 1
# ('правления', 'время') 1
# ('время', 'правления') 1
# ('на', 'правления') 1
# ('правления', 'на') 1
# ('мальте', 'на') 1
# ('на', 'мальте') 1
# ('рыцарского', 'мальте') 1
# ('мальте', 'рыцарского') 1
# ('ордена', 'рыцарского') 1
# ('рыцарского', 'ордена') 1
# ('святого', 'ордена') 1
# ('ордена', 'святого') 1
# ('иоанна', 'святого') 1
# ('святого', 'иоанна') 1
# ('с', 'иоанна') 1
# ('иоанна', 'с') 1
# ('по', 'с') 1
# ('с', 'по') 1
# ('гг', 'по') 1
# ('по', 'гг') 1
# ('в', 'гг') 1
# ('гг', 'в') 1
# ('письменными', 'время') 1
# ('время', 'письменными') 1
# ('языками', 'письменными') 1
# ('письменными', 'языками') 1
# ('были', 'языками') 1
# ('языками', 'были') 1
# ('латынь', 'были') 1
# ('были', 'латынь') 1
# ('и', 'латынь') 1
# ('латынь', 'и') 1
# ('итальянский', 'и') 1
# ('и', 'итальянский') 1
# ('сицилийский', 'итальянский') 1
# ('итальянский', 'сицилийский') 1
# ('и', 'сицилийский') 1
# ('сицилийский', 'и') 1
# ('классический', 'и') 1
# ('и', 'классический') 1
# ('однако', 'классический') 1
# ('классический', 'однако') 1
# ('известны', 'однако') 1
# ('однако', 'известны') 1
# ('отдельные', 'известны') 1
# ('известны', 'отдельные') 1
# ('попытки', 'отдельные') 1
# ('отдельные', 'попытки') 1
# ('писать', 'попытки') 1
# ('попытки', 'писать') 1
# ('и', 'писать') 1
# ('писать', 'и') 1
# ('например', 'мальтийском') 1
# ('мальтийском', 'например') 1
# ('поэма', 'например') 1
# ('например', 'поэма') 1
# ('бонамико', 'поэма') 1
# ('поэма', 'бонамико') 1
# ('bonamico', 'бонамико') 1
# ('бонамико', 'bonamico') 1
# ('первая', 'bonamico') 1
# ('bonamico', 'первая') 1
# ('опубликованная', 'первая') 1
# ('первая', 'опубликованная') 1
# ('книга', 'опубликованная') 1
# ('опубликованная', 'книга') 1
# ('на', 'книга') 1
# ('книга', 'на') 1
# ('катехизис', 'языке') 1
# ('языке', 'катехизис') 1
# ('виццино', 'катехизис') 1
# ('катехизис', 'виццино') 1
# ('wizzino', 'виццино') 1
# ('виццино', 'wizzino') 1
# ('датируется', 'wizzino') 1
# ('wizzino', 'датируется') 1
# ('годом', 'датируется') 1
# ('датируется', 'годом') 1
# ('в', 'годом') 1
# ('годом', 'в') 1
# ('мальта', 'году') 1
# ('году', 'мальта') 1
# ('присоединена', 'была') 1
# ('была', 'присоединена') 1
# ('к', 'присоединена') 1
# ('присоединена', 'к') 1
# ('великобритании', 'к') 1
# ('к', 'великобритании') 1
# ('несмотря', 'великобритании') 1
# ('великобритании', 'несмотря') 1
# ('на', 'несмотря') 1
# ('несмотря', 'на') 1
# ('это', 'на') 1
# ('на', 'это') 1
# ('xix', 'течение') 1
# ('течение', 'xix') 1
# ('века', 'xix') 1
# ('xix', 'века') 1
# ('английский', 'века') 1
# ('века', 'английский') 1
# ('язык', 'английский') 1
# ('английский', 'язык') 1
# ('не', 'язык') 1
# ('язык', 'не') 1
# ('занимал', 'не') 1
# ('не', 'занимал') 1
# ('той', 'занимал') 1
# ('занимал', 'той') 1
# ('важной', 'той') 1
# ('той', 'важной') 1
# ('позиции', 'важной') 1
# ('важной', 'позиции') 1
# ('на', 'позиции') 1
# ('позиции', 'на') 1
# ('которую', 'мальте') 1
# ('мальте', 'которую') 1
# ('занимает', 'которую') 1
# ('которую', 'занимает') 1
# ('сегодня', 'занимает') 1
# ('занимает', 'сегодня') 1
# ('официальным', 'сегодня') 1
# ('сегодня', 'официальным') 1
# ('письменным', 'официальным') 1
# ('официальным', 'письменным') 1
# ('языком', 'письменным') 1
# ('письменным', 'языком') 1
# ('оставался', 'языком') 1
# ('языком', 'оставался') 1
# ('итальянский', 'оставался') 1
# ('оставался', 'итальянский') 1
# ('разговорным', 'итальянский') 1
# ('итальянский', 'разговорным') 1
# ('мальтийский', 'разговорным') 1
# ('разговорным', 'мальтийский') 1
# ('говоря', 'мальтийский') 1
# ('мальтийский', 'говоря') 1
# ('об', 'говоря') 1
# ('говоря', 'об') 1
# ('истории', 'об') 1
# ('об', 'истории') 1
# ('мальтийского', 'истории') 1
# ('истории', 'мальтийского') 1
# ('следует', 'языка') 1
# ('языка', 'следует') 1
# ('отметить', 'следует') 1
# ('следует', 'отметить') 1
# ('деятельность', 'отметить') 1
# ('отметить', 'деятельность') 1
# ('микиля', 'деятельность') 1
# ('деятельность', 'микиля') 1
# ('антона', 'микиля') 1
# ('микиля', 'антона') 1
# ('вассалли', 'антона') 1
# ('антона', 'вассалли') 1
# ('mikiel', 'вассалли') 1
# ('вассалли', 'mikiel') 1
# ('anton', 'mikiel') 1
# ('mikiel', 'anton') 1
# ('vassal', 'anton') 1
# ('anton', 'vassal') 1
# ('он', 'vassal') 1
# ('vassal', 'он') 1
# ('составил', 'он') 1
# ('он', 'составил') 1
# ('словарь', 'составил') 1
# ('составил', 'словарь') 1
# ('мальтийского', 'словарь') 1
# ('словарь', 'мальтийского') 1
# ('и', 'языка') 1
# ('языка', 'и') 1
# ('описание', 'и') 1
# ('и', 'описание') 1
# ('мальтийской', 'описание') 1
# ('описание', 'мальтийской') 1
# ('грамматики', 'мальтийской') 1
# ('мальтийской', 'грамматики') 1
# ('перевёл', 'грамматики') 1
# ('грамматики', 'перевёл') 1
# ('на', 'перевёл') 1
# ('перевёл', 'на') 1
# ('часть', 'мальтийский') 1
# ('мальтийский', 'часть') 1
# ('нового', 'часть') 1
# ('часть', 'нового') 1
# ('завета', 'нового') 1
# ('нового', 'завета') 1
# ('в', 'завета') 1
# ('завета', 'в') 1
# ('мальте', 'году') 1
# ('году', 'мальте') 1
# ('было', 'мальте') 1
# ('мальте', 'было') 1
# ('предоставлено', 'было') 1
# ('было', 'предоставлено') 1
# ('самоуправление', 'предоставлено') 1
# ('предоставлено', 'самоуправление') 1
# ('по', 'самоуправление') 1
# ('самоуправление', 'по') 1
# ('конституции', 'по') 1
# ('по', 'конституции') 1
# ('официальными', 'конституции') 1
# ('конституции', 'официальными') 1
# ('стали', 'языками') 1
# ('языками', 'стали') 1
# ('итальянский', 'стали') 1
# ('стали', 'итальянский') 1
# ('в', 'английский') 1
# ('английский', 'в') 1
# ('мальтийский', 'году') 1
# ('году', 'мальтийский') 1
# ('получил', 'мальтийский') 1
# ('мальтийский', 'получил') 1
# ('статус', 'получил') 1
# ('получил', 'статус') 1
# ('официального', 'статус') 1
# ('статус', 'официального') 1
# ('языка', 'официального') 1
# ('официального', 'языка') 1
# ('взамен', 'языка') 1
# ('языка', 'взамен') 1
# ('итальянского', 'взамен') 1
# ('взамен', 'итальянского') 1
# ('мальтийский', 'итальянского') 1
# ('итальянского', 'мальтийский') 1
# ('остались', 'английский') 1
# ('английский', 'остались') 1
# ('государственными', 'остались') 1
# ('остались', 'государственными') 1
# ('языками', 'государственными') 1
# ('государственными', 'языками') 1
# ('и', 'языками') 1
# ('языками', 'и') 1
# ('после', 'и') 1
# ('и', 'после') 1
# ('провозглашения', 'после') 1
# ('после', 'провозглашения') 1
# ('независимости', 'провозглашения') 1
# ('провозглашения', 'независимости') 1
# ('мальты', 'независимости') 1
# ('независимости', 'мальты') 1
# ('мая', 'году') 1
# ('году', 'мая') 1
# ('года', 'мая') 1
# ('мая', 'года') 1
# ('в', 'года') 1
# ('года', 'в') 1
# ('связи', 'в') 1
# ('в', 'связи') 1
# ('со', 'связи') 1
# ('связи', 'со') 1
# ('вступлением', 'со') 1
# ('со', 'вступлением') 1
# ('мальты', 'вступлением') 1
# ('вступлением', 'мальты') 1
# ('мальтийский', 'ес') 1
# ('ес', 'мальтийский') 1
# ('стал', 'язык') 1
# ('язык', 'стал') 1
# ('официальным', 'стал') 1
# ('стал', 'официальным') 1
# ('языком', 'официальным') 1
# ('официальным', 'языком') 1
# ('ес', 'языком') 1
# ('языком', 'ес') 1
# ('письменность', 'ес') 1
# ('ес', 'письменность') 1
# ('мальтийский', 'письменность') 1
# ('письменность', 'мальтийский') 1
# ('единственный', 'мальтийский') 1
# ('мальтийский', 'единственный') 1
# ('из', 'единственный') 1
# ('единственный', 'из') 1
# ('семитских', 'из') 1
# ('из', 'семитских') 1
# ('языков', 'семитских') 1
# ('семитских', 'языков') 1
# ('с', 'языков') 1
# ('языков', 'с') 1
# ('письменностью', 'с') 1
# ('с', 'письменностью') 1
# ('на', 'письменностью') 1
# ('письменностью', 'на') 1
# ('основе', 'на') 1
# ('на', 'основе') 1
# ('латинского', 'основе') 1
# ('основе', 'латинского') 1
# ('алфавита', 'латинского') 1
# ('латинского', 'алфавита') 1
# ('в', 'алфавита') 1
# ('алфавита', 'в') 1
# ('алфавит', 'в') 1
# ('в', 'алфавит') 1
# ('иногда', 'алфавит') 1
# ('алфавит', 'иногда') 1
# ('включают', 'иногда') 1
# ('иногда', 'включают') 1
# ('букву', 'включают') 1
# ('включают', 'букву') 1
# ('c', 'букву') 1
# ('букву', 'c') 1
# ('сортируется', 'c') 1
# ('c', 'сортируется') 1
# ('после', 'сортируется') 1
# ('сортируется', 'после') 1
# ('ċ', 'после') 1
# ('после', 'ċ') 1
# ('однако', 'ċ') 1
# ('ċ', 'однако') 1
# ('эта', 'однако') 1
# ('однако', 'эта') 1
# ('буква', 'эта') 1
# ('эта', 'буква') 1
# ('встречается', 'буква') 1
# ('буква', 'встречается') 1
# ('только', 'встречается') 1
# ('встречается', 'только') 1
# ('в', 'только') 1
# ('только', 'в') 1
# ('заимствованных', 'в') 1
# ('в', 'заимствованных') 1
# ('словах', 'заимствованных') 1
# ('заимствованных', 'словах') 1
# ('в', 'словах') 1
# ('словах', 'в') 1
# ('основном', 'в') 1
# ('в', 'основном') 1
# ('итальянского', 'основном') 1
# ('основном', 'итальянского') 1
# ('и', 'итальянского') 1
# ('итальянского', 'и') 1
# ('английского', 'и') 1
# ('и', 'английского') 1
# ('происхождения', 'английского') 1
# ('английского', 'происхождения') 1
# ('напр', 'происхождения') 1
# ('происхождения', 'напр') 1
# ('camp', 'напр') 1
# ('напр', 'camp') 1
# ('кэмпинг', 'camp') 1
# ('camp', 'кэмпинг') 1
# ('с', 'кэмпинг') 1
# ('кэмпинг', 'с') 1
# ('другой', 'с') 1
# ('с', 'другой') 1
# ('стороны', 'другой') 1
# ('другой', 'стороны') 1
# ('во', 'стороны') 1
# ('стороны', 'во') 1
# ('многих', 'во') 1
# ('во', 'многих') 1
# ('словах', 'многих') 1
# ('многих', 'словах') 1
# ('c', 'словах') 1
# ('словах', 'c') 1
# ('заменяется', 'c') 1
# ('c', 'заменяется') 1
# ('на', 'заменяется') 1
# ('заменяется', 'на') 1
# ('k', 'на') 1
# ('на', 'k') 1
# ('напр', 'k') 1
# ('k', 'напр') 1
# ('kompjut', 'напр') 1
# ('напр', 'kompjut') 1
# ('компьютер', 'kompjut') 1
# ('kompjut', 'компьютер') 1
# ('от', 'компьютер') 1
# ('компьютер', 'от') 1
# ('англ', 'от') 1
# ('от', 'англ') 1
# ('характеристика', 'лингвистическая') 1
# ('лингвистическая', 'характеристика') 1
# ('просодия', 'характеристика') 1
# ('характеристика', 'просодия') 1
# ('ударение', 'просодия') 1
# ('просодия', 'ударение') 1
# ('в', 'ударение') 1
# ('ударение', 'в') 1
# ('мальтийском', 'в') 1
# ('в', 'мальтийском') 1
# ('как', 'мальтийском') 1
# ('мальтийском', 'как') 1
# ('правило', 'как') 1
# ('как', 'правило') 1
# ('падает', 'правило') 1
# ('правило', 'падает') 1
# ('на', 'падает') 1
# ('падает', 'на') 1
# ('предпоследний', 'на') 1
# ('на', 'предпоследний') 1
# ('слог', 'предпоследний') 1
# ('предпоследний', 'слог') 1
# ('если', 'слог') 1
# ('слог', 'если') 1
# ('иной', 'если') 1
# ('если', 'иной') 1
# ('слог', 'иной') 1
# ('иной', 'слог') 1
# ('не', 'слог') 1
# ('слог', 'не') 1
# ('является', 'не') 1
# ('не', 'является') 1
# ('долгим', 'является') 1
# ('является', 'долгим') 1
# ('морфология', 'долгим') 1
# ('долгим', 'морфология') 1
# ('грамматика', 'морфология') 1
# ('морфология', 'грамматика') 1
# ('мальтийского', 'грамматика') 1
# ('грамматика', 'мальтийского') 1
# ('семитского', 'языка') 1
# ('языка', 'семитского') 1
# ('типа', 'семитского') 1
# ('семитского', 'типа') 1
# ('с', 'типа') 1
# ('типа', 'с') 1
# ('романским', 'с') 1
# ('с', 'романским') 1
# ('влиянием', 'романским') 1
# ('романским', 'влиянием') 1
# ('прилагательные', 'влиянием') 1
# ('влиянием', 'прилагательные') 1
# ('следуют', 'прилагательные') 1
# ('прилагательные', 'следуют') 1
# ('за', 'следуют') 1
# ('следуют', 'за') 1
# ('существительными', 'за') 1
# ('за', 'существительными') 1
# ('отсутствует', 'существительными') 1
# ('существительными', 'отсутствует') 1
# ('наречие', 'отсутствует') 1
# ('отсутствует', 'наречие') 1
# ('как', 'наречие') 1
# ('наречие', 'как') 1
# ('самостоятельная', 'как') 1
# ('как', 'самостоятельная') 1
# ('форма', 'самостоятельная') 1
# ('самостоятельная', 'форма') 1
# ('порядок', 'форма') 1
# ('форма', 'порядок') 1
# ('слов', 'порядок') 1
# ('порядок', 'слов') 1
# ('достаточно', 'слов') 1
# ('слов', 'достаточно') 1
# ('гибок', 'достаточно') 1
# ('достаточно', 'гибок') 1
# ('имеется', 'гибок') 1
# ('гибок', 'имеется') 1
# ('определённый', 'имеется') 1
# ('имеется', 'определённый') 1
# ('артикль', 'определённый') 1
# ('определённый', 'артикль') 1
# ('как', 'артикль') 1
# ('артикль', 'как') 1
# ('в', 'как') 1
# ('как', 'в') 1
# ('арабском', 'в') 1
# ('в', 'арабском') 1
# ('и', 'арабском') 1
# ('арабском', 'и') 1
# ('иврите', 'и') 1
# ('и', 'иврите') 1
# ('артикль', 'иврите') 1
# ('иврите', 'артикль') 1
# ('ставится', 'артикль') 1
# ('артикль', 'ставится') 1
# ('и', 'ставится') 1
# ('ставится', 'и') 1
# ('перед', 'и') 1
# ('и', 'перед') 1
# ('существительными', 'перед') 1
# ('перед', 'существительными') 1
# ('и', 'существительными') 1
# ('существительными', 'и') 1
# ('прилагательными', 'перед') 1
# ('перед', 'прилагательными') 1
# ('напр', 'прилагательными') 1
# ('прилагательными', 'напр') 1
# ('l', 'напр') 1
# ('напр', 'l') 1
# ('art', 'l') 1
# ('l', 'art') 1
# ('imqaddsa', 'l') 1
# ('l', 'imqaddsa') 1
# ('святая', 'imqaddsa') 1
# ('imqaddsa', 'святая') 1
# ('земля', 'святая') 1
# ('святая', 'земля') 1
# ('дословный', 'земля') 1
# ('земля', 'дословный') 1
# ('перевод', 'дословный') 1
# ('дословный', 'перевод') 1
# ('земля', 'перевод') 1
# ('перевод', 'земля') 1
# ('ср', 'святая') 1
# ('святая', 'ср') 1
# ('также', 'ср') 1
# ('ср', 'также') 1
# ('араб', 'также') 1
# ('также', 'араб') 1
# ('الأرض', 'араб') 1
# ('араб', 'الأرض') 1
# ('المقدسة', 'الأرض') 1
# ('الأرض', 'المقدسة') 1
# ('ʾal', 'المقدسة') 1
# ('المقدسة', 'ʾal') 1
# ('ʾarḍ', 'ʾal') 1
# ('ʾal', 'ʾarḍ') 1
# ('muqaddasa', 'ʾal') 1
# ('ʾal', 'muqaddasa') 1
# ('с', 'muqaddasa') 1
# ('muqaddasa', 'с') 1
# ('тем', 'с') 1
# ('с', 'тем') 1
# ('же', 'тем') 1
# ('тем', 'же') 1
# ('значением', 'же') 1
# ('же', 'значением') 1
# ('однако', 'значением') 1
# ('значением', 'однако') 1
# ('это', 'однако') 1
# ('однако', 'это') 1
# ('правило', 'это') 1
# ('это', 'правило') 1
# ('относится', 'правило') 1
# ('правило', 'относится') 1
# ('только', 'относится') 1
# ('относится', 'только') 1
# ('к', 'только') 1
# ('только', 'к') 1
# ('семитским', 'к') 1
# ('к', 'семитским') 1
# ('словам', 'семитским') 1
# ('семитским', 'словам') 1
# ('и', 'словам') 1
# ('словам', 'и') 1
# ('не', 'и') 1
# ('и', 'не') 1
# ('действует', 'не') 1
# ('не', 'действует') 1
# ('при', 'действует') 1
# ('действует', 'при') 1
# ('употреблении', 'при') 1
# ('при', 'употреблении') 1
# ('существительных', 'употреблении') 1
# ('употреблении', 'существительных') 1
# ('и', 'существительных') 1
# ('существительных', 'и') 1
# ('прилагательных', 'и') 1
# ('и', 'прилагательных') 1
# ('романского', 'прилагательных') 1
# ('прилагательных', 'романского') 1
# ('происхождения', 'романского') 1
# ('романского', 'происхождения') 1
# ('существительные', 'происхождения') 1
# ('происхождения', 'существительные') 1
# ('изменяются', 'существительные') 1
# ('существительные', 'изменяются') 1
# ('по', 'изменяются') 1
# ('изменяются', 'по') 1
# ('числам', 'по') 1
# ('по', 'числам') 1
# ('у', 'числам') 1
# ('числам', 'у') 1
# ('существительных', 'у') 1
# ('у', 'существительных') 1
# ('романского', 'существительных') 1
# ('существительных', 'романского') 1
# ('множественное', 'происхождения') 1
# ('происхождения', 'множественное') 1
# ('число', 'множественное') 1
# ('множественное', 'число') 1
# ('образуется', 'число') 1
# ('число', 'образуется') 1
# ('добавлением', 'образуется') 1
# ('образуется', 'добавлением') 1
# ('jiet', 'или') 1
# ('или', 'jiet') 1
# ('lingwa', 'jiet') 1
# ('jiet', 'lingwa') 1
# ('язык', 'lingwa') 1
# ('lingwa', 'язык') 1
# ('ср', 'язык') 1
# ('язык', 'ср') 1
# ('итал', 'ср') 1
# ('ср', 'итал') 1
# ('lingua', 'итал') 1
# ('итал', 'lingua') 1
# ('lingwi', 'lingua') 1
# ('lingua', 'lingwi') 1
# ('arti', 'lingwi') 1
# ('lingwi', 'arti') 1
# ('искусство', 'arti') 1
# ('arti', 'искусство') 1
# ('ср', 'искусство') 1
# ('искусство', 'ср') 1
# ('art', 'итал') 1
# ('итал', 'art') 1
# ('artijiet', 'art') 1
# ('art', 'artijiet') 1
# ('с', 'artijiet') 1
# ('artijiet', 'с') 1
# ('существительными', 'с') 1
# ('с', 'существительными') 1
# ('семитского', 'существительными') 1
# ('существительными', 'семитского') 1
# ('происхождения', 'семитского') 1
# ('семитского', 'происхождения') 1
# ('всё', 'происхождения') 1
# ('происхождения', 'всё') 1
# ('гораздо', 'всё') 1
# ('всё', 'гораздо') 1
# ('сложнее', 'гораздо') 1
# ('гораздо', 'сложнее') 1
# ('такие', 'сложнее') 1
# ('сложнее', 'такие') 1
# ('существительные', 'такие') 1
# ('такие', 'существительные') 1
# ('делятся', 'существительные') 1
# ('существительные', 'делятся') 1
# ('на', 'делятся') 1
# ('делятся', 'на') 1
# ('правильные', 'на') 1
# ('на', 'правильные') 1
# ('и', 'правильные') 1
# ('правильные', 'и') 1
# ('неправильные', 'и') 1
# ('и', 'неправильные') 1
# ('у', 'неправильные') 1
# ('неправильные', 'у') 1
# ('правильных', 'у') 1
# ('у', 'правильных') 1
# ('существительных', 'правильных') 1
# ('правильных', 'существительных') 1
# ('множественное', 'существительных') 1
# ('существительных', 'множественное') 1
# ('iet', 'добавлением') 1
# ('добавлением', 'iet') 1
# ('jiet', 'iet') 1
# ('iet', 'jiet') 1
# ('соответствует', 'jiet') 1
# ('jiet', 'соответствует') 1
# ('ot', 'и') 1
# ('и', 'ot') 1
# ('в', 'ot') 1
# ('ot', 'в') 1
# ('иврите', 'в') 1
# ('в', 'иврите') 1
# ('или', 'иврите') 1
# ('иврите', 'или') 1
# ('im', 'соответствует') 1
# ('соответствует', 'im') 1
# ('в', 'im') 1
# ('im', 'в') 1
# ('у', 'иврите') 1
# ('иврите', 'у') 1
# ('неправильных', 'у') 1
# ('у', 'неправильных') 1
# ('же', 'неправильных') 1
# ('неправильных', 'же') 1
# ('существительных', 'же') 1
# ('же', 'существительных') 1
# ('изменением', 'образуется') 1
# ('образуется', 'изменением') 1
# ('гласных', 'изменением') 1
# ('изменением', 'гласных') 1
# ('внутри', 'гласных') 1
# ('гласных', 'внутри') 1
# ('ktieb', 'внутри') 1
# ('внутри', 'ktieb') 1
# ('книга', 'ktieb') 1
# ('ktieb', 'книга') 1
# ('kotba', 'книга') 1
# ('книга', 'kotba') 1
# ('raġel', 'kotba') 1
# ('kotba', 'raġel') 1
# ('человек', 'raġel') 1
# ('raġel', 'человек') 1
# ('irġiel', 'человек') 1
# ('человек', 'irġiel') 1
# ('такая', 'irġiel') 1
# ('irġiel', 'такая') 1
# ('система', 'такая') 1
# ('такая', 'система') 1
# ('очень', 'система') 1
# ('система', 'очень') 1
# ('развита', 'очень') 1
# ('очень', 'развита') 1
# ('в', 'развита') 1
# ('развита', 'в') 1
# ('встречается', 'и') 1
# ('и', 'встречается') 1
# ('в', 'встречается') 1
# ('встречается', 'в') 1
# ('кроме', 'иврите') 1
# ('иврите', 'кроме') 1
# ('множественного', 'кроме') 1
# ('кроме', 'множественного') 1
# ('числа', 'множественного') 1
# ('множественного', 'числа') 1
# ('в', 'числа') 1
# ('числа', 'в') 1
# ('имеется', 'также') 1
# ('также', 'имеется') 1
# ('двойственное', 'имеется') 1
# ('имеется', 'двойственное') 1
# ('оно', 'двойственное') 1
# ('двойственное', 'оно') 1
# ('образуется', 'оно') 1
# ('оно', 'образуется') 1
# ('с', 'образуется') 1
# ('образуется', 'с') 1
# ('помощью', 'с') 1
# ('с', 'помощью') 1
# ('суффикса', 'помощью') 1
# ('помощью', 'суффикса') 1
# ('ejn', 'суффикса') 1
# ('суффикса', 'ejn') 1
# ('или', 'ejn') 1
# ('ejn', 'или') 1
# ('ajn', 'или') 1
# ('или', 'ajn') 1
# ('и', 'ajn') 1
# ('ajn', 'и') 1
# ('употребляется', 'и') 1
# ('и', 'употребляется') 1
# ('при', 'употребляется') 1
# ('употребляется', 'при') 1
# ('указании', 'при') 1
# ('при', 'указании') 1
# ('двух', 'указании') 1
# ('указании', 'двух') 1
# ('или', 'двух') 1
# ('двух', 'или') 1
# ('парных', 'или') 1
# ('или', 'парных') 1
# ('предметов', 'парных') 1
# ('парных', 'предметов') 1
# ('напр', 'предметов') 1
# ('предметов', 'напр') 1
# ('jum', 'напр') 1
# ('напр', 'jum') 1
# ('день', 'jum') 1
# ('jum', 'день') 1
# ('jumejn', 'день') 1
# ('день', 'jumejn') 1
# ('два', 'jumejn') 1
# ('jumejn', 'два') 1
# ('дня', 'два') 1
# ('два', 'дня') 1
# ('id', 'дня') 1
# ('дня', 'id') 1
# ('рука', 'id') 1
# ('id', 'рука') 1
# ('idejn', 'рука') 1
# ('рука', 'idejn') 1
# ('обе', 'idejn') 1
# ('idejn', 'обе') 1
# ('руки', 'обе') 1
# ('обе', 'руки') 1
# ('в', 'руки') 1
# ('руки', 'в') 1
# ('глаголах', 'в') 1
# ('в', 'глаголах') 1
# ('можно', 'глаголах') 1
# ('глаголах', 'можно') 1
# ('выделить', 'можно') 1
# ('можно', 'выделить') 1
# ('семитский', 'выделить') 1
# ('выделить', 'семитский') 1
# ('корень', 'семитский') 1
# ('семитский', 'корень') 1
# ('состоящий', 'корень') 1
# ('корень', 'состоящий') 1
# ('из', 'состоящий') 1
# ('состоящий', 'из') 1
# ('трёх', 'из') 1
# ('из', 'трёх') 1
# ('согласных', 'трёх') 1
# ('трёх', 'согласных') 1
# ('глагол', 'согласных') 1
# ('согласных', 'глагол') 1
# ('спрягается', 'глагол') 1
# ('глагол', 'спрягается') 1
# ('добавлением', 'спрягается') 1
# ('спрягается', 'добавлением') 1
# ('к', 'добавлением') 1
# ('добавлением', 'к') 1
# ('этому', 'к') 1
# ('к', 'этому') 1
# ('корню', 'этому') 1
# ('этому', 'корню') 1
# ('внутренних', 'корню') 1
# ('корню', 'внутренних') 1
# ('гласных', 'внутренних') 1
# ('внутренних', 'гласных') 1
# ('а', 'гласных') 1
# ('гласных', 'а') 1
# ('суффиксов', 'также') 1
# ('также', 'суффиксов') 1
# ('и', 'суффиксов') 1
# ('суффиксов', 'и') 1
# ('приставок', 'и') 1
# ('и', 'приставок') 1
# ('пример', 'приставок') 1
# ('приставок', 'пример') 1
# ('ktb', 'пример') 1
# ('пример', 'ktb') 1
# ('корень', 'ktb') 1
# ('ktb', 'корень') 1
# ('означающий', 'корень') 1
# ('корень', 'означающий') 1
# ('писать', 'означающий') 1
# ('означающий', 'писать') 1
# ('ktibna', 'писать') 1
# ('писать', 'ktibna') 1
# ('мы', 'ktibna') 1
# ('ktibna', 'мы') 1
# ('написали', 'мы') 1
# ('мы', 'написали') 1
# ('ср', 'написали') 1
# ('написали', 'ср') 1
# ('араб', 'ср') 1
# ('ср', 'араб') 1
# ('katabna', 'араб') 1
# ('араб', 'katabna') 1
# ('иврит', 'katabna') 1
# ('katabna', 'иврит') 1
# ('katavnu', 'иврит') 1
# ('иврит', 'katavnu') 1
# ('с', 'katavnu') 1
# ('katavnu', 'с') 1
# ('теми', 'с') 1
# ('с', 'теми') 1
# ('же', 'теми') 1
# ('теми', 'же') 1
# ('значениями', 'же') 1
# ('же', 'значениями') 1
# ('существуют', 'значениями') 1
# ('значениями', 'существуют') 1
# ('два', 'существуют') 1
# ('существуют', 'два') 1
# ('времени', 'два') 1
# ('два', 'времени') 1
# ('настоящее', 'времени') 1
# ('времени', 'настоящее') 1
# ('и', 'настоящее') 1
# ('настоящее', 'и') 1
# ('прошедшее', 'и') 1
# ('и', 'прошедшее') 1
# ('перфект', 'прошедшее') 1
# ('прошедшее', 'перфект') 1
# ('для', 'перфект') 1
# ('перфект', 'для') 1
# ('выражения', 'для') 1
# ('для', 'выражения') 1
# ('будущего', 'выражения') 1
# ('выражения', 'будущего') 1
# ('используются', 'будущего') 1
# ('будущего', 'используются') 1
# ('формы', 'используются') 1
# ('используются', 'формы') 1
# ('настоящего', 'формы') 1
# ('формы', 'настоящего') 1
# ('времени', 'настоящего') 1
# ('настоящего', 'времени') 1
# ('с', 'времени') 1
# ('времени', 'с') 1
# ('добавлением', 'с') 1
# ('с', 'добавлением') 1
# ('частиц', 'добавлением') 1
# ('добавлением', 'частиц') 1
# ('или', 'частиц') 1
# ('частиц', 'или') 1
# ('вспомогательных', 'или') 1
# ('или', 'вспомогательных') 1
# ('глаголов', 'вспомогательных') 1
# ('вспомогательных', 'глаголов') 1
# ('особенностью', 'глаголов') 1
# ('глаголов', 'особенностью') 1
# ('мальтийской', 'особенностью') 1
# ('особенностью', 'мальтийской') 1
# ('глагольной', 'мальтийской') 1
# ('мальтийской', 'глагольной') 1
# ('системы', 'глагольной') 1
# ('глагольной', 'системы') 1
# ('является', 'системы') 1
# ('системы', 'является') 1
# ('то', 'является') 1
# ('является', 'то') 1
# ('что', 'то') 1
# ('то', 'что') 1
# ('к', 'что') 1
# ('что', 'к') 1
# ('по', 'романским') 1
# ('романским', 'по') 1
# ('происхождению', 'по') 1
# ('по', 'происхождению') 1
# ('глаголам', 'происхождению') 1
# ('происхождению', 'глаголам') 1
# ('добавляются', 'глаголам') 1
# ('глаголам', 'добавляются') 1
# ('арабские', 'добавляются') 1
# ('добавляются', 'арабские') 1
# ('суффиксы', 'арабские') 1
# ('арабские', 'суффиксы') 1
# ('и', 'суффиксы') 1
# ('суффиксы', 'и') 1
# ('приставки', 'и') 1
# ('и', 'приставки') 1
# ('напр', 'приставки') 1
# ('приставки', 'напр') 1
# ('iddeċidejna', 'напр') 1
# ('напр', 'iddeċidejna') 1
# ('мы', 'iddeċidejna') 1
# ('iddeċidejna', 'мы') 1
# ('решили', 'мы') 1
# ('мы', 'решили') 1
# ('где', 'решили') 1
# ('решили', 'где') 1
# ('глагол', 'ddeċieda') 1
# ('ddeċieda', 'глагол') 1
# ('ср', 'глагол') 1
# ('глагол', 'ср') 1
# ('decider', 'итал') 1
# ('итал', 'decider') 1
# ('ejna', 'decider') 1
# ('decider', 'ejna') 1
# ('арабский', 'ejna') 1
# ('ejna', 'арабский') 1
# ('элемент', 'арабский') 1
# ('арабский', 'элемент') 1
# ('образующий', 'элемент') 1
# ('элемент', 'образующий') 1
# ('форму', 'образующий') 1
# ('образующий', 'форму') 1
# ('го', 'форму') 1
# ('форму', 'го') 1
# ('лица', 'го') 1
# ('го', 'лица') 1
# ('множественного', 'лица') 1
# ('лица', 'множественного') 1
# ('прошедшего', 'числа') 1
# ('числа', 'прошедшего') 1
# ('времени', 'прошедшего') 1
# ('прошедшего', 'времени') 1
# ('в', 'времени') 1
# ('времени', 'в') 1
# ('литературном', 'в') 1
# ('в', 'литературном') 1
# ('арабском', 'литературном') 1
# ('литературном', 'арабском') 1
# ('такое', 'иврите') 1
# ('иврите', 'такое') 1
# ('происходит', 'такое') 1
# ('такое', 'происходит') 1
# ('крайне', 'происходит') 1
# ('происходит', 'крайне') 1
# ('редко', 'крайне') 1
# ('крайне', 'редко') 1
# ('однако', 'редко') 1
# ('редко', 'однако') 1
# ('подобные', 'однако') 1
# ('однако', 'подобные') 1
# ('формы', 'подобные') 1
# ('подобные', 'формы') 1
# ('встречаются', 'формы') 1
# ('формы', 'встречаются') 1
# ('в', 'встречаются') 1
# ('встречаются', 'в') 1
# ('некоторых', 'в') 1
# ('в', 'некоторых') 1
# ('арабских', 'некоторых') 1
# ('некоторых', 'арабских') 1
# ('диалектах', 'арабских') 1
# ('арабских', 'диалектах') 1
# ('лексика', 'диалектах') 1
# ('диалектах', 'лексика') 1
# ('наряду', 'лексика') 1
# ('лексика', 'наряду') 1
# ('исконным', 'с') 1
# ('с', 'исконным') 1
# ('слоем', 'исконным') 1
# ('исконным', 'слоем') 1
# ('семитской', 'слоем') 1
# ('слоем', 'семитской') 1
# ('лексики', 'семитской') 1
# ('семитской', 'лексики') 1
# ('большую', 'лексики') 1
# ('лексики', 'большую') 1
# ('роль', 'большую') 1
# ('большую', 'роль') 1
# ('играют', 'роль') 1
# ('роль', 'играют') 1
# ('романские', 'играют') 1
# ('играют', 'романские') 1
# ('в', 'романские') 1
# ('романские', 'в') 1
# ('сицилийско', 'основном') 1
# ('основном', 'сицилийско') 1
# ('итальянские', 'сицилийско') 1
# ('сицилийско', 'итальянские') 1
# ('реже', 'итальянские') 1
# ('итальянские', 'реже') 1
# ('тосканско', 'реже') 1
# ('реже', 'тосканско') 1
# ('итальянские', 'тосканско') 1
# ('тосканско', 'итальянские') 1
# ('заимствования', 'итальянские') 1
# ('итальянские', 'заимствования') 1
# ('в', 'заимствования') 1
# ('заимствования', 'в') 1
# ('базовой', 'в') 1
# ('в', 'базовой') 1
# ('лексике', 'базовой') 1
# ('базовой', 'лексике') 1
# ('преобладают', 'лексике') 1
# ('лексике', 'преобладают') 1
# ('слова', 'преобладают') 1
# ('преобладают', 'слова') 1
# ('арабского', 'слова') 1
# ('слова', 'арабского') 1
# ('происхождения', 'арабского') 1
# ('арабского', 'происхождения') 1
# ('а', 'происхождения') 1
# ('происхождения', 'а') 1
# ('для', 'а') 1
# ('а', 'для') 1
# ('обозначения', 'для') 1
# ('для', 'обозначения') 1
# ('новых', 'обозначения') 1
# ('обозначения', 'новых') 1
# ('идей', 'новых') 1
# ('новых', 'идей') 1
# ('и', 'идей') 1
# ('идей', 'и') 1
# ('предметов', 'и') 1
# ('и', 'предметов') 1
# ('в', 'предметов') 1
# ('предметов', 'в') 1
# ('качестве', 'в') 1
# ('в', 'качестве') 1
# ('терминов', 'качестве') 1
# ('качестве', 'терминов') 1
# ('относящихся', 'терминов') 1
# ('терминов', 'относящихся') 1
# ('к', 'относящихся') 1
# ('относящихся', 'к') 1
# ('государственной', 'к') 1
# ('к', 'государственной') 1
# ('деятельности', 'государственной') 1
# ('государственной', 'деятельности') 1
# ('юриспруденции', 'деятельности') 1
# ('деятельности', 'юриспруденции') 1
# ('образованию', 'юриспруденции') 1
# ('юриспруденции', 'образованию') 1
# ('искусству', 'образованию') 1
# ('образованию', 'искусству') 1
# ('литературе', 'искусству') 1
# ('искусству', 'литературе') 1
# ('широко', 'литературе') 1
# ('литературе', 'широко') 1
# ('используются', 'широко') 1
# ('широко', 'используются') 1
# ('итальянизмы', 'используются') 1
# ('используются', 'итальянизмы') 1
# ('такие', 'итальянизмы') 1
# ('итальянизмы', 'такие') 1
# ('слова', 'такие') 1
# ('такие', 'слова') 1
# ('как', 'слова') 1
# ('слова', 'как') 1
# ('raġel', 'как') 1
# ('как', 'raġel') 1
# ('mara', 'человек') 1
# ('человек', 'mara') 1
# ('женщина', 'mara') 1
# ('mara', 'женщина') 1
# ('tifel', 'женщина') 1
# ('женщина', 'tifel') 1
# ('ребёнок', 'tifel') 1
# ('tifel', 'ребёнок') 1
# ('dar', 'ребёнок') 1
# ('ребёнок', 'dar') 1
# ('дом', 'dar') 1
# ('dar', 'дом') 1
# ('xemx', 'дом') 1
# ('дом', 'xemx') 1
# ('солнце', 'xemx') 1
# ('xemx', 'солнце') 1
# ('sajf', 'солнце') 1
# ('солнце', 'sajf') 1
# ('лето', 'sajf') 1
# ('sajf', 'лето') 1
# ('по', 'лето') 1
# ('лето', 'по') 1
# ('арабские', 'происхождению') 1
# ('происхождению', 'арабские') 1
# ('а', 'арабские') 1
# ('арабские', 'а') 1
# ('skola', 'а') 1
# ('а', 'skola') 1
# ('школа', 'skola') 1
# ('skola', 'школа') 1
# ('gvern', 'школа') 1
# ('школа', 'gvern') 1
# ('правительство', 'gvern') 1
# ('gvern', 'правительство') 1
# ('repubblika', 'правительство') 1
# ('правительство', 'repubblika') 1
# ('республика', 'repubblika') 1
# ('repubblika', 'республика') 1
# ('natura', 'король') 1
# ('король', 'natura') 1
# ('природа', 'natura') 1
# ('natura', 'природа') 1
# ('pulizija', 'природа') 1
# ('природа', 'pulizija') 1
# ('полиция', 'pulizija') 1
# ('pulizija', 'полиция') 1
# ('ċentru', 'полиция') 1
# ('полиция', 'ċentru') 1
# ('центр', 'ċentru') 1
# ('ċentru', 'центр') 1
# ('teatru', 'центр') 1
# ('центр', 'teatru') 1
# ('театр', 'teatru') 1
# ('teatru', 'театр') 1
# ('differenza', 'театр') 1
# ('театр', 'differenza') 1
# ('разница', 'differenza') 1
# ('differenza', 'разница') 1
# ('романские', 'разница') 1
# ('разница', 'романские') 1
# ('итальянские', 'романские') 1
# ('романские', 'итальянские') 1
# ('по', 'итальянские') 1
# ('итальянские', 'по') 1
# ('слова', 'происхождению') 1
# ('происхождению', 'слова') 1
# ('обычно', 'слова') 1
# ('слова', 'обычно') 1
# ('отражают', 'обычно') 1
# ('обычно', 'отражают') 1
# ('сицилийское', 'отражают') 1
# ('отражают', 'сицилийское') 1
# ('произношение', 'сицилийское') 1
# ('сицилийское', 'произношение') 1
# ('в', 'произношение') 1
# ('произношение', 'в') 1
# ('то', 'в') 1
# ('в', 'то') 1
# ('время', 'то') 1
# ('то', 'время') 1
# ('как', 'время') 1
# ('время', 'как') 1
# ('литературный', 'как') 1
# ('как', 'литературный') 1
# ('итальянский', 'литературный') 1
# ('литературный', 'итальянский') 1
# ('язык', 'итальянский') 1
# ('итальянский', 'язык') 1
# ('происходит', 'язык') 1
# ('язык', 'происходит') 1
# ('из', 'происходит') 1
# ('происходит', 'из') 1
# ('тосканского', 'из') 1
# ('из', 'тосканского') 1
# ('диалекта', 'тосканского') 1
# ('тосканского', 'диалекта') 1
# ('так', 'диалекта') 1
# ('диалекта', 'так') 1
# ('конечному', 'так') 1
# ('так', 'конечному') 1
# ('o', 'конечному') 1
# ('конечному', 'o') 1
# ('в', 'o') 1
# ('o', 'в') 1
# ('тосканском', 'в') 1
# ('в', 'тосканском') 1
# ('диалекте', 'тосканском') 1
# ('тосканском', 'диалекте') 1
# ('итальянского', 'диалекте') 1
# ('диалекте', 'итальянского') 1
# ('соответствует', 'итальянского') 1
# ('итальянского', 'соответствует') 1
# ('u', 'соответствует') 1
# ('соответствует', 'u') 1
# ('в', 'u') 1
# ('u', 'в') 1
# ('как', 'языке') 1
# ('языке', 'как') 1
# ('сицилийском', 'в') 1
# ('в', 'сицилийском') 1
# ('диалекте', 'сицилийском') 1
# ('сицилийском', 'диалекте') 1
# ('например', 'диалекте') 1
# ('диалекте', 'например') 1
# ('teatru', 'например') 1
# ('например', 'teatru') 1
# ('а', 'teatru') 1
# ('teatru', 'а') 1
# ('не', 'а') 1
# ('а', 'не') 1
# ('teatro', 'не') 1
# ('не', 'teatro') 1
# ('также', 'teatro') 1
# ('teatro', 'также') 1
# ('тосканскому', 'также') 1
# ('также', 'тосканскому') 1
# ('e', 'тосканскому') 1
# ('тосканскому', 'e') 1
# ('соответствует', 'e') 1
# ('e', 'соответствует') 1
# ('arti', 'напр') 1
# ('напр', 'arti') 1
# ('fidi', 'искусство') 1
# ('искусство', 'fidi') 1
# ('вера', 'fidi') 1
# ('fidi', 'вера') 1
# ('lokali', 'вера') 1
# ('вера', 'lokali') 1
# ('местный', 'lokali') 1
# ('lokali', 'местный') 1
# ('житель', 'местный') 1
# ('местный', 'житель') 1
# ('ср', 'житель') 1
# ('житель', 'ср') 1
# ('литературные', 'ср') 1
# ('ср', 'литературные') 1
# ('итальянские', 'литературные') 1
# ('литературные', 'итальянские') 1
# ('art', 'итальянские') 1
# ('итальянские', 'art') 1
# ('fede', 'art') 1
# ('art', 'fede') 1
# ('local', 'fede') 1
# ('fede', 'local') 1
# ('как', 'local') 1
# ('local', 'как') 1
# ('романских', 'некоторых') 1
# ('некоторых', 'романских') 1
# ('языках', 'романских') 1
# ('романских', 'языках') 1
# ('звук', 'языках') 1
# ('языках', 'звук') 1
# ('ш', 'звук') 1
# ('звук', 'ш') 1
# ('передается', 'ш') 1
# ('ш', 'передается') 1
# ('буквой', 'передается') 1
# ('передается', 'буквой') 1
# ('x', 'буквой') 1
# ('буквой', 'x') 1
# ('в', 'x') 1
# ('x', 'в') 1
# ('отличие', 'в') 1
# ('в', 'отличие') 1
# ('от', 'отличие') 1
# ('отличие', 'от') 1
# ('итальянского', 'от') 1
# ('от', 'итальянского') 1
# ('где', 'итальянского') 1
# ('итальянского', 'где') 1
# ('для', 'где') 1
# ('где', 'для') 1
# ('этой', 'для') 1
# ('для', 'этой') 1
# ('цели', 'этой') 1
# ('этой', 'цели') 1
# ('используется', 'цели') 1
# ('цели', 'используется') 1
# ('диграф', 'используется') 1
# ('используется', 'диграф') 1
# ('sc', 'диграф') 1
# ('диграф', 'sc') 1
# ('ambaxxata', 'sc') 1
# ('sc', 'ambaxxata') 1
# ('посольство', 'ambaxxata') 1
# ('ambaxxata', 'посольство') 1
# ('ср', 'посольство') 1
# ('посольство', 'ср') 1
# ('ambasciata', 'итал') 1
# ('итал', 'ambasciata') 1
# ('xena', 'ambasciata') 1
# ('ambasciata', 'xena') 1
# ('сцена', 'xena') 1
# ('xena', 'сцена') 1
# ('ср', 'сцена') 1
# ('сцена', 'ср') 1
# ('scena', 'итал') 1
# ('итал', 'scena') 1
# ('обычным', 'scena') 1
# ('scena', 'обычным') 1
# ('делом', 'обычным') 1
# ('обычным', 'делом') 1
# ('в', 'делом') 1
# ('делом', 'в') 1
# ('современном', 'в') 1
# ('в', 'современном') 1
# ('мальтийском', 'современном') 1
# ('современном', 'мальтийском') 1
# ('является', 'языке') 1
# ('языке', 'является') 1
# ('заимствование', 'является') 1
# ('является', 'заимствование') 1
# ('слов', 'заимствование') 1
# ('заимствование', 'слов') 1
# ('из', 'слов') 1
# ('слов', 'из') 1
# ('английского', 'из') 1
# ('из', 'английского') 1
# ('например', 'английского') 1
# ('английского', 'например') 1
# ('strajk', 'например') 1
# ('например', 'strajk') 1
# ('забастовка', 'strajk') 1
# ('strajk', 'забастовка') 1
# ('от', 'забастовка') 1
# ('забастовка', 'от') 1
# ('strike', 'англ') 1
# ('англ', 'strike') 1
# ('televixin', 'strike') 1
# ('strike', 'televixin') 1
# ('телевидение', 'televixin') 1
# ('televixin', 'телевидение') 1
# ('от', 'телевидение') 1
# ('телевидение', 'от') 1
# ('televis', 'англ') 1
# ('англ', 'televis') 1
# ('tim', 'televis') 1
# ('televis', 'tim') 1
# ('команда', 'tim') 1
# ('tim', 'команда') 1
# ('от', 'команда') 1
# ('команда', 'от') 1
# ('team', 'англ') 1
# ('англ', 'team') 1
# ('некоторые', 'team') 1
# ('team', 'некоторые') 1
# ('слова', 'некоторые') 1
# ('некоторые', 'слова') 1
# ('сохраняют', 'слова') 1
# ('слова', 'сохраняют') 1
# ('английское', 'сохраняют') 1
# ('сохраняют', 'английское') 1
# ('написание', 'английское') 1
# ('английское', 'написание') 1
# ('например', 'написание') 1
# ('написание', 'например') 1
# ('union', 'например') 1
# ('например', 'union') 1
# ('союз', 'union') 1
# ('union', 'союз') 1
# ('объединение', 'союз') 1
# ('союз', 'объединение') 1
# ('leav', 'объединение') 1
# ('объединение', 'leav') 1
# ('отпуск', 'leav') 1
# ('leav', 'отпуск') 1
# ('bonus', 'отпуск') 1
# ('отпуск', 'bonus') 1
# ('премия', 'bonus') 1
# ('bonus', 'премия') 1
